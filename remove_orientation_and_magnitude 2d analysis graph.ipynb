# %%
# %load_ext autoreload
# %autoreload 2

# 3rd party imports
import numpy as np
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import SimpleITK as sitk
from tqdm import tqdm
import nibabel as nib


# Local imports
import modules.laplacian as laplacian
import modules.jacobian as jacobian
import modules.correspondences as correspondences

# %% [markdown]
# ## Functions

# %%
def get_neighborhood(point, points, max_dist):
    # Get the Euclidean distance between the point and all other points
    distances = np.linalg.norm(points - point, axis=1)
    
    # Get the indices of the points within the neighborhood
    neighborhood_indices = np.where(distances <= max_dist)[0]
    
    # Get the points within the neighborhood
    neighborhood = points[neighborhood_indices]
    
    #neighborhood = [pt for pt in neighborhood if pt != point]
    
    return neighborhood_indices, neighborhood


def get_magnitude(v):
    return np.linalg.norm(v)


def angle_between_vectors(v1, v2):
    # arccos (A dot B / |A||B|)
    # Compute the dot product
    dot_product = np.dot(v1, v2)
    
    # Compute the magnitudes of the vectors
    magnitude_v1 = np.linalg.norm(v1)
    magnitude_v2 = np.linalg.norm(v2)
    
    if magnitude_v1 == 0 or magnitude_v2 == 0:
        return 0, 0
    
    # Compute the cosine of the angle
    cos_theta = dot_product / (magnitude_v1 * magnitude_v2)
    
    # Clip the cosine value to the range [-1, 1] to avoid numerical issues
    cos_theta = np.clip(cos_theta, -1.0, 1.0)
    
    # Compute the angle in radians
    angle_rad = np.arccos(cos_theta)
    
    # Convert the angle to degrees
    angle_deg = np.degrees(angle_rad)
    
    return angle_rad, angle_deg

m1 = np.array([0, 1, 0])
f1 = np.array([0, 1, 4])

m2 = np.array([0, 3, 0])
f2 = np.array([0, 4, 4])

# Example vectors
# v1 = np.array([1, 0, 0])
# v2 = np.array([1, 0.5, 0])

v1 = f1 - m1
v2 = f2 - m2

# Compute the angle between the vectors
angle_rad, angle_deg = angle_between_vectors(v1, v2)

# Check if the angle exceeds a certain threshold (e.g., 45 degrees)
threshold_deg = 45
if angle_deg > threshold_deg:
    print(f"The vectors differ by a lot: {angle_deg:.2f} degrees")
else:
    print(f"The vectors do not differ by a lot: {angle_deg:.2f} degrees")
# Out:
# The vectors do not differ by a lot: 14.04 degrees

# %% [markdown]
# # Test case
# ## Load deformation field

# %%
CURR_IDX = 350  # Only consider the correspondences of this index

# Input parameters
base_path = "data/base_unique_correspondences/registered_output/deformation3d.npy"
mpoints_path = "data/base_unique_correspondences/mpoints.npy"
fpoints_path = "data/base_unique_correspondences/fpoints.npy"
lut_path = "output/final_case/lut_data_7x7.csv"

# Load the numpy array and compute the jacobian determinant
mpoints = np.load(mpoints_path)
fpoints = np.load(fpoints_path)

# Get only elements that are of the current index
mpoints = mpoints[mpoints[:, 0] == CURR_IDX]
fpoints = fpoints[fpoints[:, 0] == CURR_IDX]

# Change the 0th index in each element to 0
mpoints[:, 0] = 0
fpoints[:, 0] = 0

cvectors = fpoints - mpoints  # Correspondence vectors

print("Correspondence point shape:", fpoints.shape)
print("First five fixed points:\n", fpoints[:5])
print("First five moving points:\n", mpoints[:5])
print("First five correspondence vectors:\n", cvectors[:5])
# Out:
# Correspondence point shape: (1326, 3)
# First five fixed points:
#  [[  0.  10. 173.]
#  [  0.  10. 174.]
#  [  0.  10. 175.]
#  [  0.  10. 176.]
#  [  0.  10. 181.]]
# First five moving points:
#  [[  0.  17. 178.]
#  [  0.  17. 179.]
#  [  0.  18. 172.]
#  [  0.  18. 180.]
#  [  0.  15. 187.]]
# First five correspondence vectors:
#  [[ 0. -7. -5.]
#  [ 0. -7. -5.]
#  [ 0. -8.  3.]
#  [ 0. -8. -4.]
#  [ 0. -5. -6.]]

# %% [markdown]
# ## Remove INTERSECTING correspondences

# %%
def remove_intersections(mpoints: np.ndarray, fpoints: np.ndarray, idx: int=0) -> tuple:
    """
    Remove intersecting correspondences between the moving and fixed points.
    
    Parameters:
    mpoints (np.ndarray): The moving points.
    fpoints (np.ndarray): The fixed points.
    idx (int): The index of the correspondences.
    
    Returns:
    tuple: The moving and fixed correspondences with intersecting points removed.
    """
    mcorrespondences = []
    fcorrespondences = []

    mpts = mpoints.copy()[:, 1:]
    fpts = fpoints.copy()[:, 1:]

    # Swap correspondences if they intersect
    fpts, ipts = correspondences.swap_correspondences(mpts, fpts)
    min_intersection_count = len(ipts)
    curr_fpts = fpts
    # Keep swapping until the number of intersections no longer decreases
    while True:
        fpts, ipts_temp = correspondences.swap_correspondences(mpts, fpts)
        intersection_count = len(ipts_temp)
        #print("Number of intersecting points:", intersection_count)
        if intersection_count < min_intersection_count:
            min_intersection_count = intersection_count
            curr_fpts = fpts
        else:
            break
    fpts = curr_fpts

    # Detect intersecting line segments
    intersecting_indices, intersecting_segments, swapped_segments = correspondences.detect_intersecting_segments(mpts, fpts)

    # Remove intersecting segments from correspondences
    new_mpts = mpts.copy()
    new_fpts = fpts.copy()
    while len(intersecting_indices) != 0:
        new_mpts = [element for i, element in enumerate(new_mpts) if i not in intersecting_indices[:, 0]]
        new_fpts = [element for i, element in enumerate(new_fpts) if i not in intersecting_indices[:, 0]]
        intersecting_indices, intersecting_segments, swapped_segments = correspondences.detect_intersecting_segments(new_mpts, new_fpts)
        num_intersections = len(intersecting_indices)
        #print("Number of intersecting segments left:", num_intersections)
        if num_intersections != 0:
            intersecting_indices, intersecting_segments, swapped_segments = correspondences.detect_intersecting_segments(new_mpts, new_fpts)
    new_mpts = np.array(new_mpts)
    new_fpts = np.array(new_fpts)


    new_col = np.full((new_mpts.shape[0], 1), idx)
    new_mpts = np.hstack((new_col, new_mpts))
    new_fpts = np.hstack((new_col, new_fpts))
    mcorrespondences.append(new_mpts)
    fcorrespondences.append(new_fpts)

    mcorrespondences = np.concatenate(mcorrespondences, axis=0)
    fcorrespondences = np.concatenate(fcorrespondences, axis=0)
    return mcorrespondences, fcorrespondences

# Remove intersecting correspondences
mpoints_intersection_removed, fpoints_intersection_removed = remove_intersections(mpoints, fpoints)
print("Starting number of correspondences:", mpoints.shape[0])
print("Number of correspondences after removing intersections:", mpoints_intersection_removed.shape[0])
print("Number of correspondences removed:", mpoints.shape[0] - mpoints_intersection_removed.shape[0])
# Out:
# Starting number of correspondences: 1326
# Number of correspondences after removing intersections: 1246
# Number of correspondences removed: 80

# %% [markdown]
# ## Compute Jacobian of points with INTERSECTIONS removed.

# %%
fixed_resolution = np.zeros((1, 320, 456))

# Compute the 3D Laplacian of the ORIGINAL points and retrieve the Jacobian determinant field
deformation, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints, fpoints)
jdet = jacobian.sitk_jacobian_determinant(deformation)

# Compute the 3D Laplacian of the NEW CORRECTED points and retrieve the Jacobian determinant field
deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints_intersection_removed, fpoints_intersection_removed)
jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)

# Print the number of negative or zero Jacobian determinants
print("\nBefore - number of negative or zero Jacobian determinants:", np.sum(jdet <= 0))
print("Before - minimum Jacobian determinant:", jdet.min())
print("Before - maximum Jacobian determinant:", jdet.max())
print()

print("After - number of negative or zero Jacobian determinants:", np.sum(jdet_corrected <= 0))
print("After - minimum Jacobian determinant:", jdet_corrected.min())
print("After - maximum Jacobian determinant:", jdet_corrected.max())

# Plot the Jacobian determinant values of the original
norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints[:, 2], mpoints[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (before)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (before)")
plt.show()

# Plot the Jacobian determinant values of the corrected
norm = mcolors.TwoSlopeNorm(vmin=min(jdet_corrected.min(), -1), vcenter=0, vmax=jdet_corrected.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints_intersection_removed[:, 2], mpoints_intersection_removed[:, 1], c="g", s=1)
plt.scatter(fpoints_intersection_removed[:, 2], fpoints_intersection_removed[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (after)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (after)")
plt.show()
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.05384325981140137s
# Computing dy
# dy calculated in 0.17346763610839844s
# Computing dx
# dx calculated in 0.2729008197784424s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.0468287467956543s
# Computing dy
# dy calculated in 0.17435336112976074s
# Computing dx
# dx calculated in 0.2770700454711914s
# SITK deformation shape: (1, 320, 456, 3)
#
# Before - number of negative or zero Jacobian determinants: 386
# Before - minimum Jacobian determinant: -6.08035232834211
# Before - maximum Jacobian determinant: 9.046598660636274
#
# After - number of negative or zero Jacobian determinants: 168
# After - minimum Jacobian determinant: -4.141267670622895
# After - maximum Jacobian determinant: 8.847872374160026

# %% [markdown]
# ## Remove ORIENTATION outliers from correspondence points

# %%
MAX_DIST = 30
MAX_DEG = 60

mpoints_corrected = mpoints.copy()
fpoints_corrected = fpoints.copy()
cvectors_corrected = cvectors.copy()

# Process point orientations
outlier_found = True
num_runs = 0
total_outliers = 0
while outlier_found:
    outlier_found = False
    outlier_indices = []
    num_outliers = 0
    for i in range(len(fpoints_corrected)):
        curr_point = fpoints_corrected[i]
        curr_vector = cvectors_corrected[i]
        #print("Current point:", curr_point)
        neighborhood_idx, neighborhood = get_neighborhood(curr_point, fpoints_corrected, MAX_DIST)

        # Compute the average correspondence vector in the neighborhood
        average_vector = np.mean(cvectors_corrected[neighborhood_idx], axis=0)
        angle_rad, angle_deg = angle_between_vectors(average_vector, curr_vector)
        if angle_deg > MAX_DEG:
            num_outliers += 1
            outlier_indices.append(i)
            outlier_found = True
            #print(f"Point {i} has a large angle of {angle_deg:.2f} degrees")
            #print(angle_deg)

    # Remove outlier indices from moving and fixed points
    mpoints_corrected = np.delete(mpoints_corrected, outlier_indices, axis=0)
    fpoints_corrected = np.delete(fpoints_corrected, outlier_indices, axis=0)
    cvectors_corrected = np.delete(cvectors_corrected, outlier_indices, axis=0)
    
    print("Number of outliers:", num_outliers, f"out of {len(fpoints)} points")
    total_outliers += num_outliers
    num_runs += 1

print("\nNumber of runs:", num_runs)
print("Number of points removed:", total_outliers)
print("Number of points in the corrected points:", len(fpoints_corrected), "/", len(fpoints))
# Out:
# Number of outliers: 230 out of 1326 points
# Number of outliers: 17 out of 1326 points
# Number of outliers: 1 out of 1326 points
# Number of outliers: 0 out of 1326 points
#
# Number of runs: 4
# Number of points removed: 248
# Number of points in the corrected points: 1078 / 1326

# %% [markdown]
# ## Compute Jacobian of orientation-filtered points

# %%
fixed_resolution = np.zeros((1, 320, 456))

# Compute the 3D Laplacian of the ORIGINAL points and retrieve the Jacobian determinant field
deformation, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints, fpoints)
jdet = jacobian.sitk_jacobian_determinant(deformation)

# Compute the 3D Laplacian of the NEW CORRECTED points and retrieve the Jacobian determinant field
deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints_corrected, fpoints_corrected)
jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)

# Print the number of negative or zero Jacobian determinants
print("\nBefore - number of negative or zero Jacobian determinants:", np.sum(jdet <= 0))
print("Before - minimum Jacobian determinant:", jdet.min())
print("Before - maximum Jacobian determinant:", jdet.max())
print()

print("After - number of negative or zero Jacobian determinants:", np.sum(jdet_corrected <= 0))
print("After - minimum Jacobian determinant:", jdet_corrected.min())
print("After - maximum Jacobian determinant:", jdet_corrected.max())

# Plot the Jacobian determinant values of the original
norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints[:, 2], mpoints[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (before)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (before)")
plt.show()

# Plot the Jacobian determinant values of the corrected
norm = mcolors.TwoSlopeNorm(vmin=min(jdet_corrected.min(), -1), vcenter=0, vmax=jdet_corrected.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints_corrected[:, 2], mpoints_corrected[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (after)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (after)")
plt.show()
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.05446481704711914s
# Computing dy
# dy calculated in 0.1712510585784912s
# Computing dx
# dx calculated in 0.26940178871154785s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.04647660255432129s
# Computing dy
# dy calculated in 0.20041966438293457s
# Computing dx
# dx calculated in 0.31714463233947754s
# SITK deformation shape: (1, 320, 456, 3)
#
# Before - number of negative or zero Jacobian determinants: 386
# Before - minimum Jacobian determinant: -6.08035232834211
# Before - maximum Jacobian determinant: 9.046598660636274
#
# After - number of negative or zero Jacobian determinants: 177
# After - minimum Jacobian determinant: -3.705544075115345
# After - maximum Jacobian determinant: 6.613283330845526

# %% [markdown]
# ___

# %% [markdown]
# ## Remove MAGNITUDE outliers

# %%
MAX_MAGNITUDE_MULT_GT = 0.5
MAX_MAGNITUDE_MULT_LT = 0.5
MAX_MAGNITUDE_DIFF_GT = 2
MAX_MAGNITUDE_DIFF_LT = 2
MAX_DIST = 20
DEBUG = False


mpoints_corrected = mpoints.copy()
fpoints_corrected = fpoints.copy()
cvectors_corrected = cvectors.copy()
magnitudes = np.linalg.norm(cvectors_corrected, axis=1)

# Process point magnitudes
outlier_found = True
num_runs = 0
total_outliers = 0
while outlier_found:
    outlier_found = False
    outlier_indices = []
    num_outliers = 0
    for i in range(len(fpoints_corrected)):
        curr_point = fpoints_corrected[i]
        curr_magnitude = magnitudes[i]
        #print("Current point:", curr_point)
        neighborhood_idx, neighborhood = get_neighborhood(curr_point, fpoints_corrected, MAX_DIST)

        # Compute the average correspondence vector in the neighborhood
        average_magnitude = np.mean(magnitudes[neighborhood_idx])
        median_magnitude = np.median(magnitudes[neighborhood_idx])
        std_magnitude = np.std(magnitudes[neighborhood_idx])
        
        if DEBUG:
            print("\nCurrent point:", curr_point)
            print("Current magnitude:", curr_magnitude)
            print("Average magnitude:", average_magnitude)
            print("Median magnitude:", median_magnitude)
            print("Standard deviation of magnitudes:", std_magnitude)
        
        # Remove the point if the magnitude is greater than the average magnitude by a certain threshold
        threshold_gt = max(average_magnitude + average_magnitude * MAX_MAGNITUDE_MULT_GT, 
                           average_magnitude + MAX_MAGNITUDE_DIFF_GT)
        if curr_magnitude > threshold_gt:
            num_outliers += 1
            outlier_indices.append(i)
            outlier_found = True
            print(f"Point {i} has a larger relative magnitude of {curr_magnitude} > {threshold_gt} ({average_magnitude}).")
            
        # Remove the point if the magnitude is less than the average magnitude by a certain threshold
        threshold_lt = max(average_magnitude - average_magnitude * MAX_MAGNITUDE_MULT_LT, 
                           average_magnitude - MAX_MAGNITUDE_DIFF_LT,
                           0)
        if curr_magnitude < threshold_lt and average_magnitude - MAX_MAGNITUDE_DIFF_LT > 0:
            num_outliers += 1
            outlier_indices.append(i)
            outlier_found = True
            print(f"Point {i} has a smaller relative magnitude of {curr_magnitude} < {threshold_lt} ({average_magnitude}).")

    # Remove outlier indices from moving and fixed points
    mpoints_corrected = np.delete(mpoints_corrected, outlier_indices, axis=0)
    fpoints_corrected = np.delete(fpoints_corrected, outlier_indices, axis=0)
    cvectors_corrected = np.delete(cvectors_corrected, outlier_indices, axis=0)
    
    print("Number of outliers:", num_outliers, f"out of {len(fpoints_corrected)} points")
    total_outliers += num_outliers
    num_runs += 1
    break

print("\nNumber of runs:", num_runs)
print("Number of points removed:", total_outliers)
print("Number of points in the corrected points:", len(fpoints_corrected), "/", len(fpoints))
# Out:
# Point 50 has a larger relative magnitude of 4.47213595499958 > 3.207213595499958 (1.2072135954999579).
# Point 68 has a larger relative magnitude of 5.0 > 4.9799953278137 (2.979995327813701).
# Point 72 has a larger relative magnitude of 5.830951894845301 > 5.021324625053363 (3.0213246250533627).
# Point 79 has a larger relative magnitude of 9.219544457292887 > 7.8918708441517404 (5.261247229434494).
# Point 81 has a larger relative magnitude of 9.219544457292887 > 7.8918708441517404 (5.261247229434494).
# Point 88 has a larger relative magnitude of 6.0 > 3.824160450111475 (1.824160450111475).
# Point 91 has a larger relative magnitude of 4.47213595499958 > 3.718897292216738 (1.718897292216738).
# Point 94 has a larger relative magnitude of 4.47213595499958 > 3.3829524276059013 (1.3829524276059013).
# Point 119 has a smaller relative magnitude of 0.0 < 3.1505101394170643 (5.150510139417064).
# Point 125 has a smaller relative magnitude of 0.0 < 3.3169458057417165 (5.3169458057417165).
# Point 128 has a smaller relative magnitude of 0.0 < 3.3169458057417165 (5.3169458057417165).
# Point 153 has a larger relative magnitude of 5.0 > 3.617788148345316 (1.617788148345316).
# Point 161 has a larger relative magnitude of 2.8284271247461903 > 2.8242640687119285 (0.8242640687119286).
# Point 164 has a smaller relative magnitude of 1.0 < 1.644457560379756 (3.288915120759512).
# Point 169 has a larger relative magnitude of 7.280109889280518 > 5.1528300541692795 (3.1528300541692795).
# Point 178 has a larger relative magnitude of 10.0 > 8.327761039283956 (5.55184069285597).
# Point 195 has a larger relative magnitude of 9.486832980505138 > 9.388421211063775 (6.258947474042517).
# Point 214 has a smaller relative magnitude of 1.0 < 1.1149552559423006 (2.229910511884601).
# Point 215 has a smaller relative magnitude of 0.0 < 1.1275309463142482 (2.2550618926284964).
# Point 218 has a smaller relative magnitude of 1.0 < 1.1422368286671896 (2.284473657334379).
# Point 232 has a larger relative magnitude of 6.082762530298219 > 5.42671298575412 (3.42671298575412).
# Point 247 has a larger relative magnitude of 4.47213595499958 > 3.9776609192948325 (1.9776609192948325).
# Point 278 has a larger relative magnitude of 6.4031242374328485 > 5.7334372542637135 (3.7334372542637135).
# Point 279 has a larger relative magnitude of 7.615773105863909 > 4.656774405049864 (2.6567744050498647).
# Point 282 has a larger relative magnitude of 7.280109889280518 > 5.880654618368489 (3.880654618368489).
# Point 285 has a smaller relative magnitude of 4.0 < 5.127493002181723 (7.127493002181723).
# Point 286 has a smaller relative magnitude of 0.0 < 5.127493002181723 (7.127493002181723).
# Point 288 has a larger relative magnitude of 8.06225774829855 > 4.77075517662764 (2.77075517662764).
# Point 354 has a larger relative magnitude of 6.708203932499369 > 5.660147054648167 (3.660147054648167).
# Point 401 has a larger relative magnitude of 3.1622776601683795 > 2.9926167727346904 (0.9926167727346904).
# Point 403 has a larger relative magnitude of 6.324555320336759 > 4.476906081700035 (2.4769060817000343).
# Point 414 has a larger relative magnitude of 6.708203932499369 > 4.876329242189083 (2.876329242189083).
# Point 419 has a smaller relative magnitude of 1.4142135623730951 < 1.595093429476445 (3.19018685895289).
# Point 423 has a larger relative magnitude of 10.0 > 3.3684210526315788 (1.368421052631579).
# Point 425 has a smaller relative magnitude of 1.4142135623730951 < 1.5415880917577927 (3.0831761835155853).
# Point 438 has a larger relative magnitude of 10.63014581273465 > 3.860167860111541 (1.8601678601115408).
# Point 442 has a smaller relative magnitude of 1.0 < 1.4938074303945235 (2.987614860789047).
# Point 443 has a larger relative magnitude of 7.211102550927978 > 5.993393164079307 (3.993393164079307).
# Point 446 has a larger relative magnitude of 8.94427190999916 > 7.539446383008793 (5.026297588672529).
# Point 447 has a smaller relative magnitude of 1.4142135623730951 < 1.7868987898920667 (3.5737975797841335).
# Point 451 has a larger relative magnitude of 9.219544457292887 > 5.916047841507549 (3.916047841507549).
# Point 454 has a smaller relative magnitude of 1.4142135623730951 < 1.5029824039671649 (3.0059648079343297).
# Point 458 has a smaller relative magnitude of 1.4142135623730951 < 1.5235788064372233 (3.0471576128744466).
# Point 459 has a larger relative magnitude of 6.082762530298219 > 5.8430052387246025 (3.8430052387246025).
# Point 460 has a larger relative magnitude of 9.899494936611665 > 3.8686425352562956 (1.8686425352562959).
# Point 464 has a smaller relative magnitude of 1.4142135623730951 < 1.4715873793431686 (2.9431747586863373).
# Point 465 has a larger relative magnitude of 5.0 > 3.7962556573182713 (1.7962556573182715).
# Point 473 has a larger relative magnitude of 9.433981132056603 > 4.591724349601847 (2.5917243496018476).
# Point 476 has a smaller relative magnitude of 1.0 < 1.2514242262647624 (2.5028484525295247).
# Point 482 has a larger relative magnitude of 6.708203932499369 > 4.403229685258291 (2.40322968525829).
# Point 483 has a smaller relative magnitude of 1.0 < 1.2333643446222708 (2.4667286892445417).
# Point 488 has a larger relative magnitude of 10.816653826391969 > 4.450160146749617 (2.4501601467496177).
# Point 489 has a larger relative magnitude of 5.0 > 3.8403052805856857 (1.8403052805856857).
# Point 491 has a smaller relative magnitude of 1.0 < 1.2167958021273468 (2.4335916042546937).
# Point 495 has a smaller relative magnitude of 1.0 < 2.0549369597605063 (4.054936959760506).
# Point 496 has a larger relative magnitude of 9.055385138137417 > 6.242618936170033 (4.161745957446689).
# Point 498 has a larger relative magnitude of 3.1622776601683795 > 2.871611752517713 (0.8716117525177132).
# Point 499 has a smaller relative magnitude of 0.0 < 1.2661498097378336 (2.5322996194756673).
# Point 500 has a larger relative magnitude of 9.0 > 6.242618936170033 (4.161745957446689).
# Point 503 has a smaller relative magnitude of 1.0 < 1.2535502489239794 (2.5071004978479587).
# Point 505 has a smaller relative magnitude of 2.8284271247461903 < 4.864131864621601 (6.864131864621601).
# Point 508 has a smaller relative magnitude of 1.0 < 1.2661498097378336 (2.5322996194756673).
# Point 510 has a smaller relative magnitude of 1.0 < 2.147181022747745 (4.147181022747745).
# Point 511 has a larger relative magnitude of 8.06225774829855 > 6.442048657428282 (4.294699104952188).
# Point 513 has a smaller relative magnitude of 1.0 < 2.147181022747745 (4.147181022747745).
# Point 516 has a smaller relative magnitude of 1.0 < 4.936222206194776 (6.936222206194776).
# Point 517 has a smaller relative magnitude of 1.0 < 2.041836153673575 (4.041836153673575).
# Point 518 has a larger relative magnitude of 7.0 > 6.5053912303669605 (4.336927486911307).
# Point 523 has a smaller relative magnitude of 1.0 < 2.146941057325594 (4.146941057325594).
# Point 525 has a larger relative magnitude of 3.1622776601683795 > 2.6066926374098562 (0.6066926374098562).
# Point 531 has a smaller relative magnitude of 4.123105625617661 < 4.852377618836108 (6.852377618836108).
# Point 535 has a smaller relative magnitude of 0.0 < 1.4665065197002405 (2.933013039400481).
# Point 543 has a smaller relative magnitude of 1.0 < 1.6030595003828179 (3.2061190007656357).
# Point 549 has a smaller relative magnitude of 1.0 < 1.6030595003828179 (3.2061190007656357).
# Point 551 has a larger relative magnitude of 6.4031242374328485 > 6.040797055506573 (4.027198037004382).
# Point 561 has a smaller relative magnitude of 1.4142135623730951 < 1.462526372770993 (2.925052745541986).
# Point 562 has a smaller relative magnitude of 1.0 < 1.5322073312152347 (3.0644146624304693).
# Point 564 has a smaller relative magnitude of 1.4142135623730951 < 1.9892394394888187 (3.9784788789776373).
# Point 567 has a smaller relative magnitude of 1.0 < 1.569071878758636 (3.138143757517272).
# Point 568 has a smaller relative magnitude of 1.0 < 1.9462290290762614 (3.8924580581525228).
# Point 570 has a smaller relative magnitude of 1.0 < 1.4268772478535485 (2.853754495707097).
# Point 576 has a larger relative magnitude of 5.0 > 4.825625887584997 (2.825625887584997).
# Point 580 has a smaller relative magnitude of 1.0 < 1.004478498713831 (2.008956997427662).
# Point 583 has a smaller relative magnitude of 0.0 < 1.0325050819757107 (2.0650101639514213).
# Point 585 has a larger relative magnitude of 5.656854249492381 > 5.178650923088396 (3.1786509230883966).
# Point 591 has a larger relative magnitude of 8.48528137423857 > 4.179580373935699 (2.179580373935699).
# Point 598 has a smaller relative magnitude of 3.1622776601683795 < 3.5404454981428266 (5.540445498142827).
# Point 604 has a larger relative magnitude of 8.06225774829855 > 5.271049239386699 (3.271049239386699).
# Point 609 has a smaller relative magnitude of 2.0 < 2.3664856437226467 (4.366485643722647).
# Point 616 has a larger relative magnitude of 5.656854249492381 > 5.5445969075831 (3.5445969075830996).
# Point 623 has a larger relative magnitude of 6.708203932499369 > 6.54972846558397 (4.366485643722647).
# Point 627 has a smaller relative magnitude of 2.0 < 4.0330184668170075 (6.0330184668170075).
# Point 628 has a larger relative magnitude of 6.082762530298219 > 5.8992969009146625 (3.8992969009146625).
# Point 633 has a larger relative magnitude of 8.06225774829855 > 5.658255951697328 (3.658255951697328).
# Point 635 has a smaller relative magnitude of 0.0 < 1.8986895039743874 (3.797379007948775).
# Point 636 has a smaller relative magnitude of 1.0 < 2.597471400258641 (4.597471400258641).
# Point 643 has a smaller relative magnitude of 1.0 < 1.6940839537295938 (3.3881679074591875).
# Point 646 has a smaller relative magnitude of 1.4142135623730951 < 1.6940839537295938 (3.3881679074591875).
# Point 653 has a smaller relative magnitude of 1.0 < 1.5320349292986513 (3.0640698585973025).
# Point 654 has a smaller relative magnitude of 2.23606797749979 < 2.597471400258641 (4.597471400258641).
# Point 655 has a larger relative magnitude of 9.219544457292887 > 8.857517558861371 (5.905011705907581).
# Point 657 has a larger relative magnitude of 6.0 > 2.877589915377152 (0.8775899153771517).
# Point 666 has a smaller relative magnitude of 1.0 < 2.513048239076861 (4.513048239076861).
# Point 671 has a larger relative magnitude of 4.47213595499958 > 4.393654962838651 (2.3936549628386516).
# Point 672 has a larger relative magnitude of 5.385164807134504 > 3.7210305577070946 (1.7210305577070948).
# Point 674 has a larger relative magnitude of 7.280109889280518 > 6.513369426744322 (4.342246284496214).
# Point 675 has a larger relative magnitude of 7.0710678118654755 > 6.203689825140694 (4.1357932167604625).
# Point 686 has a smaller relative magnitude of 1.0 < 1.2179936000842733 (2.4359872001685465).
# Point 692 has a smaller relative magnitude of 1.0 < 1.2081313724087235 (2.416262744817447).
# Point 694 has a larger relative magnitude of 5.385164807134504 > 3.9122561752301053 (1.9122561752301053).
# Point 697 has a smaller relative magnitude of 1.0 < 1.2081313724087235 (2.416262744817447).
# Point 699 has a smaller relative magnitude of 1.0 < 1.1758444112584245 (2.351688822516849).
# Point 702 has a smaller relative magnitude of 1.0 < 1.2081313724087235 (2.416262744817447).
# Point 704 has a smaller relative magnitude of 0.0 < 1.2269680813131387 (2.4539361626262775).
# Point 705 has a larger relative magnitude of 5.656854249492381 > 4.522234762429363 (2.5222347624293633).
# Point 708 has a smaller relative magnitude of 0.0 < 1.3191994005983405 (2.638398801196681).
# Point 716 has a larger relative magnitude of 8.06225774829855 > 6.53999466115682 (4.359996440771213).
# Point 720 has a larger relative magnitude of 5.830951894845301 > 4.445454437492607 (2.4454544374926077).
# Point 723 has a larger relative magnitude of 4.47213595499958 > 4.445454437492607 (2.4454544374926077).
# Point 727 has a larger relative magnitude of 5.385164807134504 > 4.233286449349343 (2.2332864493493427).
# Point 735 has a larger relative magnitude of 6.4031242374328485 > 5.569598378089627 (3.569598378089627).
# Point 745 has a smaller relative magnitude of 3.0 < 3.009567826079783 (5.009567826079783).
# Point 749 has a smaller relative magnitude of 3.0 < 3.009567826079783 (5.009567826079783).
# Point 755 has a larger relative magnitude of 5.656854249492381 > 5.426842912640204 (3.4268429126402036).
# Point 759 has a larger relative magnitude of 6.708203932499369 > 5.404377496185456 (3.4043774961854556).
# Point 765 has a larger relative magnitude of 5.830951894845301 > 5.404377496185456 (3.4043774961854556).
# Point 771 has a larger relative magnitude of 7.615773105863909 > 4.326829268701882 (2.3268292687018826).
# Point 774 has a smaller relative magnitude of 1.0 < 1.0951838606519302 (2.1903677213038604).
# Point 778 has a smaller relative magnitude of 1.0 < 1.0979033995276999 (2.1958067990553998).
# Point 781 has a smaller relative magnitude of 1.0 < 1.5275232459472894 (3.0550464918945788).
# Point 783 has a smaller relative magnitude of 0.0 < 1.008796541561445 (2.01759308312289).
# Point 787 has a smaller relative magnitude of 1.0 < 1.5275232459472894 (3.0550464918945788).
# Point 789 has a smaller relative magnitude of 0.0 < 1.008796541561445 (2.01759308312289).
# Point 793 has a smaller relative magnitude of 0.0 < 1.008796541561445 (2.01759308312289).
# Point 794 has a larger relative magnitude of 9.0 > 5.387328927399987 (3.387328927399987).
# Point 795 has a larger relative magnitude of 12.041594578792296 > 3.197793762775622 (1.1977937627756223).
# Point 796 has a smaller relative magnitude of 0.0 < 1.008796541561445 (2.01759308312289).
# Point 800 has a larger relative magnitude of 5.0990195135927845 > 4.146302034115162 (2.1463020341151617).
# Point 805 has a larger relative magnitude of 4.123105625617661 > 3.6318984752029557 (1.6318984752029555).
# Point 815 has a larger relative magnitude of 5.0 > 4.056383674659993 (2.056383674659993).
# Point 822 has a smaller relative magnitude of 1.0 < 1.5429203831199676 (3.085840766239935).
# Point 825 has a larger relative magnitude of 9.0 > 5.3616704922112355 (3.361670492211235).
# Point 832 has a smaller relative magnitude of 2.0 < 2.068143616624843 (4.068143616624843).
# Point 835 has a smaller relative magnitude of 2.0 < 2.006019857733164 (4.006019857733164).
# Point 836 has a smaller relative magnitude of 1.0 < 1.610404013749864 (3.220808027499728).
# Point 837 has a larger relative magnitude of 9.0 > 5.264408314196147 (3.264408314196147).
# Point 844 has a larger relative magnitude of 8.246211251235321 > 6.041844328024594 (4.027896218683063).
# Point 849 has a smaller relative magnitude of 1.0 < 1.5710231096369696 (3.142046219273939).
# Point 850 has a smaller relative magnitude of 3.605551275463989 < 3.845461774661425 (5.845461774661425).
# Point 852 has a smaller relative magnitude of 1.4142135623730951 < 1.9598726800885007 (3.9197453601770014).
# Point 855 has a smaller relative magnitude of 0.0 < 1.5710231096369696 (3.142046219273939).
# Point 856 has a larger relative magnitude of 7.0710678118654755 > 5.180114426583071 (3.1801144265830703).
# Point 857 has a smaller relative magnitude of 3.1622776601683795 < 3.845461774661425 (5.845461774661425).
# Point 873 has a smaller relative magnitude of 1.0 < 1.5710231096369696 (3.142046219273939).
# Point 874 has a smaller relative magnitude of 3.0 < 3.845461774661425 (5.845461774661425).
# Point 883 has a smaller relative magnitude of 1.0 < 1.0154715090949105 (2.030943018189821).
# Point 884 has a smaller relative magnitude of 3.1622776601683795 < 3.845461774661425 (5.845461774661425).
# Point 898 has a smaller relative magnitude of 2.23606797749979 < 3.8993831595262964 (5.899383159526296).
# Point 908 has a smaller relative magnitude of 0.0 < 1.974935661865776 (3.949871323731552).
# Point 909 has a larger relative magnitude of 6.708203932499369 > 3.3159609105443564 (1.3159609105443564).
# Point 915 has a larger relative magnitude of 8.0 > 5.515559257318744 (3.515559257318744).
# Point 916 has a larger relative magnitude of 9.0 > 8.999566313503168 (5.999710875668779).
# Point 921 has a smaller relative magnitude of 0.0 < 1.974935661865776 (3.949871323731552).
# Point 925 has a larger relative magnitude of 7.810249675906654 > 4.315191265945367 (2.3151912659453666).
# Point 928 has a smaller relative magnitude of 3.0 < 4.7312941835149 (6.7312941835149).
# Point 929 has a larger relative magnitude of 8.48528137423857 > 6.254504961580482 (4.169669974386988).
# Point 936 has a larger relative magnitude of 9.486832980505138 > 9.441540643352404 (6.294360428901603).
# Point 937 has a larger relative magnitude of 8.06225774829855 > 6.254504961580482 (4.169669974386988).
# Point 938 has a larger relative magnitude of 8.54400374531753 > 6.254504961580482 (4.169669974386988).
# Point 946 has a larger relative magnitude of 8.06225774829855 > 6.254504961580482 (4.169669974386988).
# Point 947 has a smaller relative magnitude of 1.0 < 1.1521622210862459 (2.3043244421724918).
# Point 949 has a smaller relative magnitude of 1.4142135623730951 < 1.6686142550136798 (3.3372285100273595).
# Point 950 has a larger relative magnitude of 8.0 > 5.557924064661689 (3.5579240646616888).
# Point 952 has a smaller relative magnitude of 0.0 < 1.974935661865776 (3.949871323731552).
# Point 957 has a smaller relative magnitude of 1.0 < 1.1521622210862459 (2.3043244421724918).
# Point 959 has a smaller relative magnitude of 0.0 < 1.974935661865776 (3.949871323731552).
# Point 966 has a smaller relative magnitude of 2.0 < 4.1413807761543096 (6.1413807761543096).
# Point 967 has a smaller relative magnitude of 0.0 < 1.983543663072465 (3.96708732614493).
# Point 968 has a smaller relative magnitude of 0.0 < 1.427891705578729 (2.855783411157458).
# Point 972 has a larger relative magnitude of 9.055385138137417 > 5.949871323731552 (3.949871323731552).
# Point 973 has a larger relative magnitude of 8.54400374531753 > 5.777895330760335 (3.7778953307603347).
# Point 974 has a smaller relative magnitude of 0.0 < 1.5891368605446998 (3.1782737210893997).
# Point 981 has a smaller relative magnitude of 3.0 < 4.1746468411317945 (6.1746468411317945).
# Point 982 has a larger relative magnitude of 8.54400374531753 > 5.957795108415589 (3.9577951084155893).
# Point 986 has a smaller relative magnitude of 3.1622776601683795 < 4.064599753282701 (6.064599753282701).
# Point 987 has a smaller relative magnitude of 0.0 < 1.8436953017718571 (3.6873906035437143).
# Point 1000 has a smaller relative magnitude of 4.47213595499958 < 5.129026638977371 (7.129026638977371).
# Point 1005 has a smaller relative magnitude of 0.0 < 1.0962549188498152 (2.1925098376996304).
# Point 1012 has a smaller relative magnitude of 0.0 < 1.0962549188498152 (2.1925098376996304).
# Point 1015 has a larger relative magnitude of 8.06225774829855 > 7.123634420531793 (4.749089613687862).
# Point 1021 has a larger relative magnitude of 5.0990195135927845 > 3.947525021955321 (1.9475250219553208).
# Point 1025 has a larger relative magnitude of 5.0 > 3.912431502623642 (1.9124315026236423).
# Point 1031 has a larger relative magnitude of 8.602325267042627 > 8.392778062915712 (5.595185375277141).
# Point 1042 has a smaller relative magnitude of 1.4142135623730951 < 1.824180922089002 (3.648361844178004).
# Point 1058 has a smaller relative magnitude of 2.23606797749979 < 2.813363453744138 (4.813363453744138).
# Point 1067 has a larger relative magnitude of 6.4031242374328485 > 3.602233192332349 (1.6022331923323492).
# Point 1068 has a larger relative magnitude of 6.324555320336759 > 5.765899775778472 (3.7658997757784713).
# Point 1069 has a larger relative magnitude of 9.055385138137417 > 7.962962861346368 (5.308641907564245).
# Point 1079 has a larger relative magnitude of 8.06225774829855 > 7.962962861346368 (5.308641907564245).
# Point 1086 has a larger relative magnitude of 9.219544457292887 > 5.509981278174989 (3.5099812781749886).
# Point 1113 has a larger relative magnitude of 5.0 > 3.720485020373581 (1.720485020373581).
# Point 1124 has a larger relative magnitude of 6.4031242374328485 > 3.9612225224859627 (1.9612225224859627).
# Point 1153 has a larger relative magnitude of 8.94427190999916 > 4.3265281531074535 (2.3265281531074535).
# Point 1169 has a smaller relative magnitude of 2.23606797749979 < 3.029497281571545 (5.029497281571545).
# Point 1176 has a smaller relative magnitude of 2.0 < 2.82996661699499 (4.82996661699499).
# Point 1183 has a larger relative magnitude of 7.211102550927978 > 6.511143732442903 (4.340762488295269).
# Point 1185 has a larger relative magnitude of 11.40175425099138 > 11.271066461878695 (7.5140443079191295).
# Point 1191 has a smaller relative magnitude of 0.0 < 1.214963401055127 (2.429926802110254).
# Point 1194 has a larger relative magnitude of 5.830951894845301 > 5.430133188508465 (3.4301331885084654).
# Point 1205 has a smaller relative magnitude of 2.0 < 2.839572601003484 (4.839572601003484).
# Point 1207 has a larger relative magnitude of 4.242640687119285 > 3.4601346471140517 (1.4601346471140517).
# Point 1213 has a smaller relative magnitude of 1.0 < 2.0757306131719497 (4.07573061317195).
# Point 1215 has a smaller relative magnitude of 1.0 < 1.8939244147251568 (3.7878488294503136).
# Point 1222 has a smaller relative magnitude of 1.0 < 1.0722071500648365 (2.144414300129673).
# Point 1226 has a smaller relative magnitude of 0.0 < 1.0722071500648365 (2.144414300129673).
# Point 1233 has a smaller relative magnitude of 1.0 < 1.1972071500648365 (2.394414300129673).
# Point 1242 has a smaller relative magnitude of 1.0 < 1.2386579829444482 (2.4773159658888964).
# Point 1247 has a larger relative magnitude of 5.830951894845301 > 4.70343129450462 (2.7034312945046204).
# Point 1252 has a larger relative magnitude of 5.830951894845301 > 4.53621690203633 (2.536216902036329).
# Point 1263 has a larger relative magnitude of 7.615773105863909 > 5.804451146291411 (3.8044511462914117).
# Point 1272 has a smaller relative magnitude of 1.0 < 1.4213807520531183 (2.8427615041062366).
# Point 1277 has a smaller relative magnitude of 1.0 < 1.9991526567628346 (3.998305313525669).
# Point 1295 has a smaller relative magnitude of 1.0 < 1.147993151368949 (2.295986302737898).
# Point 1296 has a smaller relative magnitude of 1.0 < 1.1553928089373964 (2.3107856178747928).
# Point 1298 has a smaller relative magnitude of 1.0 < 1.3806463907807847 (2.7612927815615693).
# Point 1302 has a smaller relative magnitude of 1.0 < 1.9080895034469862 (3.8161790068939725).
# Point 1303 has a larger relative magnitude of 4.242640687119285 > 2.730966823619377 (0.7309668236193773).
# Point 1320 has a larger relative magnitude of 6.324555320336759 > 5.062969515909266 (3.0629695159092667).
# Number of outliers: 228 out of 1098 points
#
# Number of runs: 1
# Number of points removed: 228
# Number of points in the corrected points: 1098 / 1326

# %% [markdown]
# ## Compute Jacobian of magnitude-filtered points

# %%
fixed_resolution = np.zeros((1, 320, 456))

# Compute the 3D Laplacian of the ORIGINAL points and retrieve the Jacobian determinant field
deformation, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints, fpoints)
jdet = jacobian.sitk_jacobian_determinant(deformation)

# Compute the 3D Laplacian of the NEW CORRECTED points and retrieve the Jacobian determinant field
deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints_corrected, fpoints_corrected)
jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)

# Print the number of negative or zero Jacobian determinants
print("\nBefore - number of negative or zero Jacobian determinants:", np.sum(jdet <= 0))
print("Before - minimum Jacobian determinant:", jdet.min())
print("Before - maximum Jacobian determinant:", jdet.max())
print()

print("After - number of negative or zero Jacobian determinants:", np.sum(jdet_corrected <= 0))
print("After - minimum Jacobian determinant:", jdet_corrected.min())
print("After - maximum Jacobian determinant:", jdet_corrected.max())

# Plot the Jacobian determinant values of the original
norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints[:, 2], mpoints[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (before)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (before)")
plt.show()

# Plot the Jacobian determinant values of the corrected
norm = mcolors.TwoSlopeNorm(vmin=min(jdet_corrected.min(), -1), vcenter=0, vmax=jdet_corrected.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints_corrected[:, 2], mpoints_corrected[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (after)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (after)")
plt.show()
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.05011153221130371s
# Computing dy
# dy calculated in 0.16422343254089355s
# Computing dx
# dx calculated in 0.25794458389282227s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.04549384117126465s
# Computing dy
# dy calculated in 0.1645197868347168s
# Computing dx
# dx calculated in 0.2658684253692627s
# SITK deformation shape: (1, 320, 456, 3)
#
# Before - number of negative or zero Jacobian determinants: 386
# Before - minimum Jacobian determinant: -6.08035232834211
# Before - maximum Jacobian determinant: 9.046598660636274
#
# After - number of negative or zero Jacobian determinants: 204
# After - minimum Jacobian determinant: -3.9731419957669822
# After - maximum Jacobian determinant: 7.441483621937265

# %% [markdown]
# ___
# # Combine all

# %%
def get_negative_jdet_stats(jdet: np.ndarray, debug: bool = False) -> tuple:
    """
    Get the average, median, and standard deviation of the negative Jacobian determinants.
    
    Parameters:
    jdet (np.ndarray): The Jacobian determinant field.
    
    Returns:
    Tuple[float, float, float]: The average, median, standard deviation, min, and max of the negative Jacobian determinants.
    """
    negative_jdet = jdet[jdet <= 0]
    jdet_mean = np.mean(negative_jdet)
    jdet_median = np.median(negative_jdet)
    jdet_std = np.std(negative_jdet)
    jdet_min = negative_jdet.min()
    jdet_max = negative_jdet.max()
    if debug:
        print("Number of negative Jacobian determinants:", len(negative_jdet))
        print("Average negative Jacobian determinant:", jdet_mean)
        print("Median negative Jacobian determinant:", jdet_median)
        print("Standard deviation of negative Jacobian determinants:", jdet_std)
        print("Minimum negative Jacobian determinant:", jdet_min)
        print("Maximum negative Jacobian determinant:", jdet_max)
    return jdet_mean, jdet_median, jdet_std, jdet_min, jdet_max

# %% [markdown]
# ### Run intersection removal

# %%
# Start with intersecting point removal
mpoints_intersection_removed, fpoints_intersection_removed = remove_intersections(mpoints, fpoints)
curr_mpoints = mpoints_intersection_removed.copy()
curr_fpoints = fpoints_intersection_removed.copy()
curr_cvectors = curr_fpoints - curr_mpoints

print("Starting number of correspondences:", mpoints.shape[0])
print("Number of correspondences after removing intersections:", mpoints_intersection_removed.shape[0])
print("Number of correspondences removed:", mpoints.shape[0] - mpoints_intersection_removed.shape[0])
# Out:
# Starting number of correspondences: 1326
# Number of correspondences after removing intersections: 1246
# Number of correspondences removed: 80

# %%
fixed_resolution = np.zeros((1, 320, 456))

# Compute the 3D Laplacian of the ORIGINAL points and retrieve the Jacobian determinant field
deformation, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints, fpoints)
jdet = jacobian.sitk_jacobian_determinant(deformation)

# Compute the 3D Laplacian of the NEW CORRECTED points and retrieve the Jacobian determinant field
deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, curr_mpoints, curr_fpoints)
jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)

print("\nBase Jdet before modifications:")
get_negative_jdet_stats(jdet, debug=True)
print()

# Print the number of negative or zero Jacobian determinants
print("\nBefore - number of negative or zero Jacobian determinants:", np.sum(jdet <= 0))
print("Before - minimum Jacobian determinant:", jdet.min())
print("Before - maximum Jacobian determinant:", jdet.max())
print()

print("After - number of negative or zero Jacobian determinants:", np.sum(jdet_corrected <= 0))
print("After - minimum Jacobian determinant:", jdet_corrected.min())
print("After - maximum Jacobian determinant:", jdet_corrected.max())
print()

get_negative_jdet_stats(jdet_corrected, debug=True)

# Plot the Jacobian determinant values of the original
norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints[:, 2], mpoints[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (before)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (before)")
plt.show()

# Plot the Jacobian determinant values of the corrected
norm = mcolors.TwoSlopeNorm(vmin=min(jdet_corrected.min(), -1), vcenter=0, vmax=jdet_corrected.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(curr_mpoints[:, 2], curr_mpoints[:, 1], c="g", s=1)
plt.scatter(curr_fpoints[:, 2], curr_fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (after)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (after)")
plt.show()
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.051686763763427734s
# Computing dy
# dy calculated in 0.16350293159484863s
# Computing dx
# dx calculated in 0.2580392360687256s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.04678463935852051s
# Computing dy
# dy calculated in 0.1677839756011963s
# Computing dx
# dx calculated in 0.26734066009521484s
# SITK deformation shape: (1, 320, 456, 3)
#
# Base Jdet before modifications:
# Number of negative Jacobian determinants: 386
# Average negative Jacobian determinant: -0.5640707394702855
# Median negative Jacobian determinant: -0.31449281575664245
# Standard deviation of negative Jacobian determinants: 0.7454131492787323
# Minimum negative Jacobian determinant: -6.08035232834211
# Maximum negative Jacobian determinant: -0.00046179012442182366
#
#
# Before - number of negative or zero Jacobian determinants: 386
# Before - minimum Jacobian determinant: -6.08035232834211
# Before - maximum Jacobian determinant: 9.046598660636274
#
# After - number of negative or zero Jacobian determinants: 168
# After - minimum Jacobian determinant: -4.141267670622895
# After - maximum Jacobian determinant: 8.847872374160026
#
# Number of negative Jacobian determinants: 168
# Average negative Jacobian determinant: -0.5052638130946148
# Median negative Jacobian determinant: -0.2552384828593206
# Standard deviation of negative Jacobian determinants: 0.6771247434543606
# Minimum negative Jacobian determinant: -4.141267670622895
# Maximum negative Jacobian determinant: -0.003348518762839821

# %% [markdown]
# ### Run orientation removal

# %%
# Now remove orientation outliers
MAX_DIST = 30
MAX_DEG = 60  # 60 default

mpoints_corrected = curr_mpoints.copy()
fpoints_corrected = curr_fpoints.copy()
cvectors_corrected = curr_cvectors.copy()

# Process point orientations
outlier_found = True
num_runs = 0
total_outliers = 0
while outlier_found:
    outlier_found = False
    outlier_indices = []
    num_outliers = 0
    for i in range(len(fpoints_corrected)):
        curr_point = fpoints_corrected[i]
        curr_vector = cvectors_corrected[i]
        #print("Current point:", curr_point)
        neighborhood_idx, neighborhood = get_neighborhood(curr_point, fpoints_corrected, MAX_DIST)

        # Compute the average correspondence vector in the neighborhood
        average_vector = np.mean(cvectors_corrected[neighborhood_idx], axis=0)
        angle_rad, angle_deg = angle_between_vectors(average_vector, curr_vector)
        if angle_deg > MAX_DEG:
            num_outliers += 1
            outlier_indices.append(i)
            outlier_found = True
            #print(f"Point {i} has a large angle of {angle_deg:.2f} degrees")
            #print(angle_deg)

    # Remove outlier indices from moving and fixed points
    mpoints_corrected = np.delete(mpoints_corrected, outlier_indices, axis=0)
    fpoints_corrected = np.delete(fpoints_corrected, outlier_indices, axis=0)
    cvectors_corrected = np.delete(cvectors_corrected, outlier_indices, axis=0)
    
    print("Number of outliers:", num_outliers, f"out of {len(curr_fpoints)} points")
    total_outliers += num_outliers
    num_runs += 1

print("\nNumber of runs:", num_runs)
print("Number of points removed:", total_outliers)
print("Number of points in the corrected points:", len(fpoints_corrected), "/", len(curr_fpoints))

curr_mpoints = mpoints_corrected.copy()
curr_fpoints = fpoints_corrected.copy()
curr_cvectors = curr_fpoints - curr_mpoints
# Out:
# Number of outliers: 184 out of 1246 points
# Number of outliers: 18 out of 1246 points
# Number of outliers: 7 out of 1246 points
# Number of outliers: 2 out of 1246 points
# Number of outliers: 1 out of 1246 points
# Number of outliers: 0 out of 1246 points
#
# Number of runs: 6
# Number of points removed: 212
# Number of points in the corrected points: 1034 / 1246

# %% [markdown]
# ### Check intermediary Jacobian

# %%
fixed_resolution = np.zeros((1, 320, 456))

# Compute the 3D Laplacian of the ORIGINAL points and retrieve the Jacobian determinant field
deformation, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints, fpoints)
jdet = jacobian.sitk_jacobian_determinant(deformation)

# Compute the 3D Laplacian of the NEW CORRECTED points and retrieve the Jacobian determinant field
deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, curr_mpoints, curr_fpoints)
jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)

# Print the number of negative or zero Jacobian determinants
print("\nBefore - number of negative or zero Jacobian determinants:", np.sum(jdet <= 0))
print("Before - minimum Jacobian determinant:", jdet.min())
print("Before - maximum Jacobian determinant:", jdet.max())
print()

print("After - number of negative or zero Jacobian determinants:", np.sum(jdet_corrected <= 0))
print("After - minimum Jacobian determinant:", jdet_corrected.min())
print("After - maximum Jacobian determinant:", jdet_corrected.max())
print() 

get_negative_jdet_stats(jdet_corrected, debug=True)

# Plot the Jacobian determinant values of the original
norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints[:, 2], mpoints[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (before)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (before)")
plt.show()

# Plot the Jacobian determinant values of the corrected
norm = mcolors.TwoSlopeNorm(vmin=min(jdet_corrected.min(), -1), vcenter=0, vmax=jdet_corrected.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(curr_mpoints[:, 2], curr_mpoints[:, 1], c="g", s=1)
plt.scatter(curr_fpoints[:, 2], curr_fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (after)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (after)")
plt.show()
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.05187582969665527s
# Computing dy
# dy calculated in 0.1690380573272705s
# Computing dx
# dx calculated in 0.27117204666137695s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.04728198051452637s
# Computing dy
# dy calculated in 0.18793082237243652s
# Computing dx
# dx calculated in 0.29880738258361816s
# SITK deformation shape: (1, 320, 456, 3)
#
# Before - number of negative or zero Jacobian determinants: 386
# Before - minimum Jacobian determinant: -6.08035232834211
# Before - maximum Jacobian determinant: 9.046598660636274
#
# After - number of negative or zero Jacobian determinants: 92
# After - minimum Jacobian determinant: -3.473978516992518
# After - maximum Jacobian determinant: 5.79103541966788
#
# Number of negative Jacobian determinants: 92
# Average negative Jacobian determinant: -0.39018871384276604
# Median negative Jacobian determinant: -0.2305628409373301
# Standard deviation of negative Jacobian determinants: 0.5084644359434645
# Minimum negative Jacobian determinant: -3.473978516992518
# Maximum negative Jacobian determinant: -0.00019547213481059533

# %% [markdown]
# ### Run magnitude removal

# %%
# Now run magnitude
MAX_MAGNITUDE_MULT_GT = 0.5
MAX_MAGNITUDE_MULT_LT = 0.5
MAX_MAGNITUDE_DIFF_GT = 2
MAX_MAGNITUDE_DIFF_LT = 2
MAX_DIST = 20
DEBUG = False


mpoints_corrected = curr_mpoints.copy()
fpoints_corrected = curr_fpoints.copy()
cvectors_corrected = curr_cvectors.copy()
magnitudes = np.linalg.norm(cvectors_corrected, axis=1)

# Process point magnitudes
outlier_found = True
num_runs = 0
total_outliers = 0
while outlier_found:
    outlier_found = False
    outlier_indices = []
    num_outliers = 0
    for i in range(len(fpoints_corrected)):
        curr_point = fpoints_corrected[i]
        curr_magnitude = magnitudes[i]
        #print("Current point:", curr_point)
        neighborhood_idx, neighborhood = get_neighborhood(curr_point, fpoints_corrected, MAX_DIST)

        # Compute the average correspondence vector in the neighborhood
        average_magnitude = np.mean(magnitudes[neighborhood_idx])
        median_magnitude = np.median(magnitudes[neighborhood_idx])
        std_magnitude = np.std(magnitudes[neighborhood_idx])
        
        if DEBUG:
            print("\nCurrent point:", curr_point)
            print("Current magnitude:", curr_magnitude)
            print("Average magnitude:", average_magnitude)
            print("Median magnitude:", median_magnitude)
            print("Standard deviation of magnitudes:", std_magnitude)
        
        # Remove the point if the magnitude is greater than the average magnitude by a certain threshold
        threshold_gt = max(average_magnitude + average_magnitude * MAX_MAGNITUDE_MULT_GT, 
                           average_magnitude + MAX_MAGNITUDE_DIFF_GT)
        if curr_magnitude > threshold_gt:
            num_outliers += 1
            outlier_indices.append(i)
            outlier_found = True
            print(f"Point {i} has a larger relative magnitude of {curr_magnitude} > {threshold_gt} ({average_magnitude}).")
            
        # Remove the point if the magnitude is less than the average magnitude by a certain threshold
        threshold_lt = max(average_magnitude - average_magnitude * MAX_MAGNITUDE_MULT_LT, 
                           average_magnitude - MAX_MAGNITUDE_DIFF_LT,
                           0)
        if curr_magnitude < threshold_lt and average_magnitude - MAX_MAGNITUDE_DIFF_LT > 0:
            num_outliers += 1
            outlier_indices.append(i)
            outlier_found = True
            print(f"Point {i} has a smaller relative magnitude of {curr_magnitude} < {threshold_lt} ({average_magnitude}).")

    # Remove outlier indices from moving and fixed points
    mpoints_corrected = np.delete(mpoints_corrected, outlier_indices, axis=0)
    fpoints_corrected = np.delete(fpoints_corrected, outlier_indices, axis=0)
    cvectors_corrected = np.delete(cvectors_corrected, outlier_indices, axis=0)
    
    print("Number of outliers:", num_outliers, f"out of {len(fpoints_corrected)} points")
    total_outliers += num_outliers
    num_runs += 1
    break

print("\n\nNumber of runs:", num_runs)
print("Number of points removed:", total_outliers)
print("Number of points in the corrected points:", len(fpoints_corrected), "/", len(curr_fpoints))

curr_mpoints = mpoints_corrected.copy()
curr_fpoints = fpoints_corrected.copy()
curr_cvectors = curr_fpoints - curr_mpoints
# Out:
# Point 33 has a smaller relative magnitude of 0.0 < 1.1765306226698662 (2.3530612453397324).
# Point 47 has a larger relative magnitude of 7.211102550927978 > 5.236923245394814 (3.236923245394814).
# Point 48 has a larger relative magnitude of 3.605551275463989 > 3.1630286277012187 (1.163028627701219).
# Point 61 has a smaller relative magnitude of 0.0 < 1.4200713635801094 (2.840142727160219).
# Point 65 has a larger relative magnitude of 5.830951894845301 > 5.308412907387316 (3.3084129073873156).
# Point 72 has a larger relative magnitude of 9.219544457292887 > 7.725952270616403 (5.150634847077602).
# Point 74 has a larger relative magnitude of 9.219544457292887 > 7.725952270616403 (5.150634847077602).
# Point 80 has a larger relative magnitude of 4.47213595499958 > 3.0476517761412576 (1.0476517761412576).
# Point 105 has a smaller relative magnitude of 0.0 < 2.9985639364982966 (4.998563936498297).
# Point 110 has a smaller relative magnitude of 0.0 < 3.162296223352196 (5.162296223352196).
# Point 112 has a larger relative magnitude of 2.23606797749979 > 2.194788273163307 (0.1947882731633069).
# Point 113 has a smaller relative magnitude of 0.0 < 3.162296223352196 (5.162296223352196).
# Point 143 has a smaller relative magnitude of 1.4142135623730951 < 1.570434548167862 (3.140869096335724).
# Point 144 has a smaller relative magnitude of 1.4142135623730951 < 1.5709442758781633 (3.1418885517563266).
# Point 153 has a larger relative magnitude of 5.0990195135927845 > 4.928643909538991 (2.928643909538991).
# Point 154 has a larger relative magnitude of 10.0 > 8.273282352137564 (5.515521568091709).
# Point 186 has a smaller relative magnitude of 1.0 < 1.0472030314431522 (2.0944060628863044).
# Point 187 has a smaller relative magnitude of 0.0 < 1.0375442645376869 (2.0750885290753738).
# Point 189 has a smaller relative magnitude of 1.0 < 1.0375442645376869 (2.0750885290753738).
# Point 194 has a larger relative magnitude of 2.8284271247461903 > 2.8199077617585053 (0.8199077617585052).
# Point 238 has a larger relative magnitude of 8.94427190999916 > 4.75377795881333 (2.7537779588133304).
# Point 243 has a larger relative magnitude of 6.708203932499369 > 4.58159438301718 (2.5815943830171793).
# Point 254 has a smaller relative magnitude of 3.0 < 4.304165600007188 (6.304165600007188).
# Point 259 has a larger relative magnitude of 5.830951894845301 > 5.646500652168864 (3.6465006521688648).
# Point 276 has a larger relative magnitude of 6.082762530298219 > 5.792488794413776 (3.7924887944137757).
# Point 300 has a larger relative magnitude of 6.324555320336759 > 5.562740424036811 (3.5627404240368112).
# Point 322 has a larger relative magnitude of 5.0990195135927845 > 4.932916653253968 (2.932916653253968).
# Point 325 has a larger relative magnitude of 3.1622776601683795 > 2.6380164589365798 (0.6380164589365795).
# Point 336 has a larger relative magnitude of 6.708203932499369 > 4.8372460539033995 (2.8372460539033995).
# Point 340 has a smaller relative magnitude of 1.4142135623730951 < 1.5229824039671649 (3.0459648079343298).
# Point 345 has a smaller relative magnitude of 1.4142135623730951 < 1.5069886578498741 (3.0139773156997482).
# Point 354 has a larger relative magnitude of 6.4031242374328485 > 3.857942926429872 (1.857942926429872).
# Point 355 has a larger relative magnitude of 5.0 > 3.2727272727272725 (1.2727272727272727).
# Point 357 has a smaller relative magnitude of 1.0 < 1.6645431619420918 (3.3290863238841837).
# Point 360 has a larger relative magnitude of 8.94427190999916 > 8.435213788973632 (5.6234758593157546).
# Point 361 has a smaller relative magnitude of 1.4142135623730951 < 1.667739025269703 (3.335478050539406).
# Point 367 has a smaller relative magnitude of 1.4142135623730951 < 1.6594478381339508 (3.3188956762679016).
# Point 371 has a smaller relative magnitude of 1.4142135623730951 < 1.6987802443911968 (3.3975604887823936).
# Point 372 has a larger relative magnitude of 6.082762530298219 > 5.715257466914117 (3.715257466914117).
# Point 378 has a larger relative magnitude of 5.0 > 3.7691902099026438 (1.7691902099026438).
# Point 383 has a larger relative magnitude of 9.433981132056603 > 4.91750205960067 (2.9175020596006696).
# Point 385 has a smaller relative magnitude of 1.0 < 1.4424791843106983 (2.8849583686213967).
# Point 388 has a larger relative magnitude of 8.48528137423857 > 3.7891302254509878 (1.7891302254509878).
# Point 389 has a larger relative magnitude of 6.708203932499369 > 4.724231592915645 (2.724231592915645).
# Point 390 has a smaller relative magnitude of 1.0 < 1.3610790145877363 (2.7221580291754726).
# Point 396 has a larger relative magnitude of 5.0 > 3.7518230995863444 (1.7518230995863442).
# Point 398 has a smaller relative magnitude of 5.0990195135927845 < 5.312442956999869 (7.312442956999869).
# Point 402 has a larger relative magnitude of 3.1622776601683795 > 2.71591792551399 (0.7159179255139902).
# Point 406 has a larger relative magnitude of 7.211102550927978 > 4.702433573824372 (2.7024335738243725).
# Point 407 has a smaller relative magnitude of 5.0 < 5.345270645540544 (7.345270645540544).
# Point 408 has a larger relative magnitude of 10.04987562112089 > 6.519667863730762 (4.3464452424871745).
# Point 418 has a larger relative magnitude of 3.1622776601683795 > 2.436938444135493 (0.4369384441354927).
# Point 428 has a smaller relative magnitude of 0.0 < 1.6747911153240667 (3.3495822306481333).
# Point 439 has a smaller relative magnitude of 1.0 < 1.739656343828733 (3.479312687657466).
# Point 447 has a smaller relative magnitude of 1.0 < 1.7060136516954862 (3.4120273033909725).
# Point 449 has a smaller relative magnitude of 0.0 < 2.355820862057154 (4.355820862057154).
# Point 452 has a smaller relative magnitude of 1.0 < 1.7584490278561598 (3.5168980557123195).
# Point 454 has a smaller relative magnitude of 1.0 < 1.6744898347830763 (3.3489796695661527).
# Point 468 has a larger relative magnitude of 5.656854249492381 > 5.244361672546699 (3.244361672546699).
# Point 473 has a larger relative magnitude of 8.48528137423857 > 3.93248198872031 (1.93248198872031).
# Point 480 has a smaller relative magnitude of 3.0 < 3.0207525827661827 (5.020752582766183).
# Point 485 has a larger relative magnitude of 8.06225774829855 > 5.336285542084298 (3.3362855420842976).
# Point 498 has a larger relative magnitude of 7.615773105863909 > 5.7744968532503655 (3.7744968532503655).
# Point 507 has a smaller relative magnitude of 0.0 < 3.0316304438316806 (5.031630443831681).
# Point 508 has a smaller relative magnitude of 1.0 < 1.8872484266251828 (3.7744968532503655).
# Point 535 has a larger relative magnitude of 7.0710678118654755 > 5.828621075529512 (3.828621075529511).
# Point 542 has a smaller relative magnitude of 1.0 < 1.092617825840201 (2.185235651680402).
# Point 547 has a smaller relative magnitude of 1.0 < 1.0817174689356461 (2.1634349378712923).
# Point 551 has a smaller relative magnitude of 1.0 < 1.0817174689356461 (2.1634349378712923).
# Point 553 has a smaller relative magnitude of 1.0 < 1.1502273735878756 (2.3004547471757513).
# Point 556 has a smaller relative magnitude of 1.0 < 1.0817174689356461 (2.1634349378712923).
# Point 558 has a smaller relative magnitude of 0.0 < 1.2077387422672694 (2.415477484534539).
# Point 561 has a smaller relative magnitude of 0.0 < 1.2713039392287047 (2.5426078784574093).
# Point 575 has a smaller relative magnitude of 1.0 < 1.0990173561734848 (2.1980347123469697).
# Point 576 has a larger relative magnitude of 6.4031242374328485 > 5.716119206976214 (3.716119206976214).
# Point 583 has a larger relative magnitude of 4.123105625617661 > 3.9919221250606416 (1.9919221250606418).
# Point 586 has a smaller relative magnitude of 2.23606797749979 < 3.9633740433322266 (5.963374043332227).
# Point 590 has a larger relative magnitude of 5.830951894845301 > 5.644346855668173 (3.6443468556681737).
# Point 593 has a larger relative magnitude of 6.4031242374328485 > 5.687303312712719 (3.687303312712719).
# Point 598 has a larger relative magnitude of 5.830951894845301 > 5.644346855668173 (3.6443468556681737).
# Point 604 has a larger relative magnitude of 5.656854249492381 > 4.097734520459262 (2.0977345204592623).
# Point 607 has a smaller relative magnitude of 1.0 < 1.016580950804359 (2.033161901608718).
# Point 611 has a smaller relative magnitude of 1.0 < 1.0170834038590364 (2.034166807718073).
# Point 617 has a larger relative magnitude of 4.242640687119285 > 4.173130033100707 (2.1731300331007066).
# Point 624 has a larger relative magnitude of 9.0 > 5.54634257071981 (3.5463425707198097).
# Point 625 has a larger relative magnitude of 12.041594578792296 > 3.2109800136273305 (1.2109800136273305).
# Point 629 has a larger relative magnitude of 5.0990195135927845 > 3.9651977259814197 (1.9651977259814195).
# Point 632 has a larger relative magnitude of 4.123105625617661 > 3.1662848516197863 (1.1662848516197861).
# Point 638 has a smaller relative magnitude of 0.0 < 1.6682312882924355 (3.336462576584871).
# Point 640 has a larger relative magnitude of 5.0 > 3.787455389580059 (1.787455389580059).
# Point 647 has a smaller relative magnitude of 1.0 < 1.7479045842702172 (3.4958091685404344).
# Point 653 has a smaller relative magnitude of 1.4142135623730951 < 1.8447018765277299 (3.6894037530554598).
# Point 655 has a smaller relative magnitude of 2.0 < 2.1703667227055012 (4.170366722705501).
# Point 658 has a smaller relative magnitude of 2.0 < 2.106548778298232 (4.106548778298232).
# Point 660 has a larger relative magnitude of 9.0 > 5.831603139973107 (3.831603139973107).
# Point 667 has a larger relative magnitude of 9.219544457292887 > 4.9499949051427015 (2.9499949051427015).
# Point 677 has a smaller relative magnitude of 0.0 < 1.9158015699865536 (3.831603139973107).
# Point 678 has a larger relative magnitude of 7.0710678118654755 > 5.992762445146441 (3.9927624451464414).
# Point 679 has a smaller relative magnitude of 3.1622776601683795 < 3.5972332452868114 (5.597233245286811).
# Point 694 has a smaller relative magnitude of 3.0 < 3.5972332452868114 (5.597233245286811).
# Point 700 has a smaller relative magnitude of 3.1622776601683795 < 3.5972332452868114 (5.597233245286811).
# Point 711 has a smaller relative magnitude of 2.23606797749979 < 3.5972332452868114 (5.597233245286811).
# Point 720 has a smaller relative magnitude of 1.4142135623730951 < 4.542554042668821 (6.542554042668821).
# Point 721 has a smaller relative magnitude of 0.0 < 1.3444654681898707 (2.6889309363797413).
# Point 726 has a larger relative magnitude of 8.0 > 6.668084885711815 (4.445389923807877).
# Point 727 has a larger relative magnitude of 9.0 > 8.636869739834584 (5.757913159889722).
# Point 732 has a smaller relative magnitude of 0.0 < 1.3444654681898707 (2.6889309363797413).
# Point 736 has a larger relative magnitude of 5.656854249492381 > 4.454977647648455 (2.454977647648455).
# Point 739 has a smaller relative magnitude of 3.0 < 4.529791025780823 (6.529791025780823).
# Point 744 has a larger relative magnitude of 9.486832980505138 > 9.21295588693679 (6.1419705912911935).
# Point 745 has a larger relative magnitude of 8.06225774829855 > 5.2927968548988 (3.2927968548988003).
# Point 751 has a smaller relative magnitude of 1.0 < 1.1508013926304916 (2.3016027852609833).
# Point 753 has a smaller relative magnitude of 1.4142135623730951 < 2.26745726253625 (4.26745726253625).
# Point 754 has a larger relative magnitude of 8.0 > 7.157022557707364 (4.771348371804909).
# Point 756 has a smaller relative magnitude of 0.0 < 1.3444654681898707 (2.6889309363797413).
# Point 762 has a smaller relative magnitude of 0.0 < 1.3444654681898707 (2.6889309363797413).
# Point 766 has a smaller relative magnitude of 0.0 < 1.3444654681898707 (2.6889309363797413).
# Point 767 has a smaller relative magnitude of 0.0 < 1.4304964580377337 (2.8609929160754675).
# Point 769 has a larger relative magnitude of 8.54400374531753 > 5.894952731682044 (3.894952731682044).
# Point 770 has a smaller relative magnitude of 0.0 < 1.6137295886808827 (3.2274591773617654).
# Point 775 has a larger relative magnitude of 8.54400374531753 > 6.167008491829902 (4.111338994553268).
# Point 777 has a smaller relative magnitude of 0.0 < 1.8880720389505525 (3.776144077901105).
# Point 785 has a smaller relative magnitude of 0.0 < 1.084668987717486 (2.169337975434972).
# Point 790 has a smaller relative magnitude of 0.0 < 1.084668987717486 (2.169337975434972).
# Point 807 has a smaller relative magnitude of 1.4142135623730951 < 3.791232241609409 (5.791232241609409).
# Point 853 has a smaller relative magnitude of 0.0 < 5.851207610259758 (7.851207610259758).
# Point 888 has a larger relative magnitude of 6.082762530298219 > 6.0826169060492195 (4.055077937366146).
# Point 893 has a larger relative magnitude of 17.804493814764857 > 12.627720301978238 (8.418480201318825).
# Point 916 has a smaller relative magnitude of 4.242640687119285 < 4.37699929986424 (6.37699929986424).
# Point 920 has a larger relative magnitude of 7.211102550927978 > 6.079802067452255 (4.0532013783015035).
# Point 926 has a smaller relative magnitude of 0.0 < 1.1207801980365741 (2.2415603960731483).
# Point 928 has a larger relative magnitude of 5.830951894845301 > 5.465925529501286 (3.4659255295012854).
# Point 936 has a smaller relative magnitude of 3.605551275463989 < 3.7988861997735963 (5.798886199773596).
# Point 938 has a larger relative magnitude of 4.242640687119285 > 3.0973698010786794 (1.0973698010786794).
# Point 978 has a smaller relative magnitude of 0.0 < 1.2856232805863161 (2.5712465611726323).
# Point 988 has a smaller relative magnitude of 0.0 < 1.4020838133785605 (2.804167626757121).
# Point 990 has a smaller relative magnitude of 1.0 < 1.9987239534908494 (3.997447906981699).
# Point 1003 has a larger relative magnitude of 8.06225774829855 > 4.542662998584142 (2.542662998584141).
# Point 1008 has a smaller relative magnitude of 1.0 < 1.1925196157032756 (2.385039231406551).
# Point 1009 has a smaller relative magnitude of 1.0 < 1.1925196157032756 (2.385039231406551).
# Point 1014 has a larger relative magnitude of 4.242640687119285 > 2.69253351270786 (0.6925335127078598).
# Point 1028 has a larger relative magnitude of 6.324555320336759 > 5.256236700620043 (3.256236700620043).
# Number of outliers: 142 out of 892 points
#
#
# Number of runs: 1
# Number of points removed: 142
# Number of points in the corrected points: 892 / 1034

# %%
print("Final number of correspondences:", curr_mpoints.shape[0])
# Out:
# Final number of correspondences: 892

# %% [markdown]
# ## Compute Jacobian of final combined operation

# %%
fixed_resolution = np.zeros((1, 320, 456))

# Compute the 3D Laplacian of the ORIGINAL points and retrieve the Jacobian determinant field
deformation, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints, fpoints)
jdet = jacobian.sitk_jacobian_determinant(deformation)

# Compute the 3D Laplacian of the NEW CORRECTED points and retrieve the Jacobian determinant field
deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, curr_mpoints, curr_fpoints)
jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)

# Print the number of negative or zero Jacobian determinants
print("\nBefore - number of negative or zero Jacobian determinants:", np.sum(jdet <= 0))
print("Before - minimum Jacobian determinant:", jdet.min())
print("Before - maximum Jacobian determinant:", jdet.max())
print()

print("After - number of negative or zero Jacobian determinants:", np.sum(jdet_corrected <= 0))
print("After - minimum Jacobian determinant:", jdet_corrected.min())
print("After - maximum Jacobian determinant:", jdet_corrected.max())
print()

get_negative_jdet_stats(jdet_corrected, debug=True)

# Plot the Jacobian determinant values of the original
norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints[:, 2], mpoints[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (before)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (before)")
plt.show()

# Plot the Jacobian determinant values of the corrected
norm = mcolors.TwoSlopeNorm(vmin=min(jdet_corrected.min(), -1), vcenter=0, vmax=jdet_corrected.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(curr_mpoints[:, 2], curr_mpoints[:, 1], c="g", s=1)
plt.scatter(curr_fpoints[:, 2], curr_fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (after)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (after)")
plt.show()
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.0512995719909668s
# Computing dy
# dy calculated in 0.16543221473693848s
# Computing dx
# dx calculated in 0.2604846954345703s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.04665207862854004s
# Computing dy
# dy calculated in 0.189589262008667s
# Computing dx
# dx calculated in 0.31400084495544434s
# SITK deformation shape: (1, 320, 456, 3)
#
# Before - number of negative or zero Jacobian determinants: 386
# Before - minimum Jacobian determinant: -6.08035232834211
# Before - maximum Jacobian determinant: 9.046598660636274
#
# After - number of negative or zero Jacobian determinants: 27
# After - minimum Jacobian determinant: -0.8647245957286207
# After - maximum Jacobian determinant: 3.9868281439344906
#
# Number of negative Jacobian determinants: 27
# Average negative Jacobian determinant: -0.18502100950380906
# Median negative Jacobian determinant: -0.09607994258469835
# Standard deviation of negative Jacobian determinants: 0.20047009973805854
# Minimum negative Jacobian determinant: -0.8647245957286207
# Maximum negative Jacobian determinant: -0.000987044747038153

# %%
# Save the final corrected correspondences
#np.save("output/mpoints_27.npy", curr_mpoints)
#np.save("output/fpoints_27.npy", curr_fpoints)
#np.save("output/deformation_27.npy", deformation_corrected)
#np.save("output/jdet_27.npy", jdet_corrected)

# %%
# Plot average negative Jdets (overall severity)

# Values to plot
values = [-0.56407, -0.50526, -0.39018, -0.18502]

f = plt.figure(figsize=(5, 5))

# Create a line plot
plt.plot(values, marker='o', linestyle='-', color='r')

# Add labels and title
plt.xlabel('Correspondence corrections')
plt.xticks([0, 1, 2, 3], ['Base', 'Intersection', 'Orientation', 'Magnitude'])
plt.ylabel('Average negative Jdet')
plt.ylim(top=0.1)
plt.title('Average negative Jdet over iterative corrections')

# Draw a horizontal line at y = 0
plt.axhline(y=0, color='b', linestyle='--')

# Show the plot
plt.grid(True)
plt.show()
f.clear()
plt.close(f)

# %%
# Plot minimum Jdet values (worst case)

# Values to plot
values = [-6.08035, -4.14126, -3.47397, -0.86472]

f = plt.figure(figsize=(5, 5))

# Create a line plot
plt.plot(values, marker='o', linestyle='-', color='r')

# Add labels and title
plt.xlabel('Correspondence corrections')
plt.xticks([0, 1, 2, 3], ['Base', 'Intersection', 'Orientation', 'Magnitude'])
plt.ylabel('Min. negative Jdet')
plt.ylim(top=1.25)
plt.title('Minimum negative Jdet over iterative corrections')

# Draw a horizontal line at y = 0
plt.axhline(y=0, color='b', linestyle='--')

# Show the plot
plt.grid(True)
plt.show()
f.clear()
plt.close(f)

# %% [markdown]
# ___
# # Run analysis on output

# %%
def get_negative_jdet_coords(jdet: np.ndarray) -> np.ndarray:
    """
    Get the coordinates of the negative Jacobian determinants.
    
    Parameters:
    jdet (np.ndarray): The Jacobian determinant field.
    
    Returns:
    np.ndarray: The coordinates of the negative Jacobian determinants.
    """
    return np.argwhere(jdet <= 0)


import matplotlib.patheffects as path_effects


def show_point(coord: np.ndarray, deformation: np.ndarray, jdet: np.ndarray, fpoints: np.ndarray=None, n: int=5):
    """
    Shows a plot of n x n points around a coordinate.
    
    Parameters:
    coord (np.ndarray): The coordinate.
    deformation (np.ndarray): The deformation field.
    jdet (np.ndarray): The Jacobian determinant field.
    fpoints (np.ndarray): The fixed points (optional).
    n (int): The size of the grid centering the current coordinate. Should be an odd number, otherwise size is increased + 1.
    """
    # Get the n x n points around the coordinate
    z, y, x = coord
    y_min = max(y - (n // 2), 0)
    y_max = min(y + (n // 2), jdet.shape[1])
    x_min = max(x - (n // 2), 0)
    x_max = min(x + (n // 2), jdet.shape[2])
    
    # Get only fpoints from the current slice if any are provided
    if fpoints is not None:
        fpoints = fpoints[fpoints[:, 0] == coord[0]]
    
    # Adjust font size based on n
    font_size = max(8, 16 - n)
    
    # Normalize the colorbar for the Jacobian determinant field
    norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
    
    # Subplot 1: Plot the Jacobian determinant field
    gridspec = {'width_ratios': [1, 1, 0.1]}
    fig, ax = plt.subplots(1, 3, figsize=(10, 5), gridspec_kw=gridspec)
    im = ax[0].imshow(jdet[0], cmap="seismic", norm=norm, interpolation='nearest')
    ax[0].set_xlim(x_min - 0.5, x_max + 0.5)
    ax[0].set_ylim(y_max + 0.5, y_min - 0.5)
    ax[0].set_title(f"Jacobian determinant field\n{tuple(coord)}")
    
    # Write the jacobian determinant values on the plot
    for j in range(y_min, y_max + 1):
        for i in range(x_min, x_max + 1):
            is_negative_jdet = (jdet[0, j, i] <= 0)
            if is_negative_jdet:
                text_color = 'blue'
                text_weight = 'bold'
            else:
                text_color = 'black'
                text_weight = 'normal'
            t = ax[0].text(i, j, f"{jdet[0, j, i]:.2f}", ha='center', va='center', color=text_color, fontsize=font_size, weight=text_weight)
            if is_negative_jdet:
                t.set_path_effects([path_effects.Stroke(linewidth=1, foreground="white"), path_effects.Normal()])
    
    # Subplot 2: Plot the displacement vector field
    ax[1].imshow(jdet[0], cmap="seismic", norm=norm, interpolation='nearest')
    for j in range(y_min, y_max + 1):
        for i in range(x_min, x_max + 1):
            y_displacement = deformation[2][0][j][i]
            x_displacement = deformation[1][0][j][i]
            
            # Adjust the magnitude for visual clarity
            magnitude = np.sqrt(y_displacement**2 + x_displacement**2) * 2
            adjusted_y_displacement = y_displacement
            adjusted_x_displacement = x_displacement
            if magnitude != 0:
                adjusted_y_displacement /= magnitude
                adjusted_x_displacement /= magnitude
                
            # If the point is a correspondence, color green, otherwise make it black
            is_correspondence = fpoints is not None and any(np.array_equal((coord[0], j, i), arr) for arr in fpoints)
            if is_correspondence: 
                arrow_color = 'green'
            else:
                arrow_color = 'black'
                
            # Plot the displacement vector
            ax[1].annotate(
                '', 
                xy=(i + adjusted_x_displacement, j + adjusted_y_displacement), 
                xytext=(i, j), 
                arrowprops=dict(color=arrow_color, shrink=0.045, headwidth=4, headlength=4.5, width=0.75)
            )
            
            # Color based on Jacobian determinant value
            is_negative_jdet = (jdet[0, j, i] <= 0)
            if is_negative_jdet:  # If the Jacobian determinant is negative, color blue/bold
                text_color = 'blue'
                text_weight = 'bold'
            elif is_correspondence:  # If the point is a correspondence, color green/bold
                text_color = 'green'
                text_weight = 'bold'
            else:  # If the Jacobian determinant is positive, color black/normal
                text_color = 'black'
                text_weight = 'normal'
            # Set text of displacement vector
            t = ax[1].text(i, j, f"{round(y_displacement, 2)}\n\n{round(x_displacement, 2)}", ha='center', va='center', color=text_color, weight=text_weight, fontsize=font_size)
            if is_negative_jdet:
                t.set_path_effects([path_effects.Stroke(linewidth=1, foreground="white"), path_effects.Normal()])


    # Ensure x and y axes show integer coordinates
    ax[1].set_xlim(x_min - 0.5, x_max + 0.5)
    ax[1].set_ylim(y_max + 0.5, y_min - 0.5)
    ax[1].set_title(f"Displacement field\n{tuple(coord)}")
    for axis in ax:
        axis.xaxis.set_major_locator(plt.MaxNLocator(integer=True))
        axis.yaxis.set_major_locator(plt.MaxNLocator(integer=True))
       
    # Create a colorbar for the Jacobian determinant field
    cax = ax[2]
    plt.colorbar(im, cax=cax)
    plt.tight_layout()
    plt.show()

    # Clear from memory
    fig.clear()
    plt.close(fig)

# %% [markdown]
# ## Try specific indices

# %%
jdet_idx = 0

for i in range(0):
    jdet_idx = i
    print("JDET INDEX:", jdet_idx)
    # Get the coordinates of the negative Jacobian determinants
    negative_jdet_coords = get_negative_jdet_coords(jdet_corrected)
    for coord in negative_jdet_coords:
        coord = tuple(coord)
        info_str = str(coord) + " " + str(jdet_corrected[coord])
        print(info_str)
    print()
    print("Current Jdet coordinate index:", jdet_idx)
    print("Number of negative Jdet coords:", len(negative_jdet_coords))


    # Analyze a sample negative Jacobian determinant coordinate
    sample_coord = negative_jdet_coords[jdet_idx]
    print("Negative Jacobian determinant coordinate:", sample_coord)
    jacobian.surrounding_points(sample_coord, deformation_corrected, jdet_corrected)
    show_point(sample_coord, deformation_corrected, jdet_corrected, fpoints=fpoints_corrected, n=9)
    print()
    print()

# %% [markdown]
# # Grid

# %%
import networkx as nx

# %% [markdown]
# ## Load correspondences with intersections removed already

# %%
CURR_IDX = 350  # Only consider the correspondences of this index

# Input parameters
base_path = "data/corrected_correspondences_count_touching/registered_output/deformation3d.npy"
mpoints_path = "data/corrected_correspondences_count_touching/mpoints.npy"
fpoints_path = "data/corrected_correspondences_count_touching/fpoints.npy"

# Load the numpy array and compute the jacobian determinant
mpoints = np.load(mpoints_path)
fpoints = np.load(fpoints_path)

# Get only elements that are of the current index
mpoints = mpoints[mpoints[:, 0] == CURR_IDX]
fpoints = fpoints[fpoints[:, 0] == CURR_IDX]

# Change the 0th index in each element to 0
mpoints[:, 0] = 0
fpoints[:, 0] = 0

cvectors = fpoints - mpoints  # Correspondence vectors

print("Correspondence point shape:", fpoints.shape)
print("First five fixed points:\n", fpoints[:5])
print("First five moving points:\n", mpoints[:5])
print("First five correspondence vectors:\n", cvectors[:5])
# Out:
# Correspondence point shape: (1246, 3)
# First five fixed points:
#  [[  0.  10. 175.]
#  [  0.  10. 174.]
#  [  0.  10. 176.]
#  [  0.  10. 181.]
#  [  0.  10. 188.]]
# First five moving points:
#  [[  0.  17. 179.]
#  [  0.  18. 172.]
#  [  0.  18. 180.]
#  [  0.  15. 187.]
#  [  0.  15. 188.]]
# First five correspondence vectors:
#  [[ 0. -7. -4.]
#  [ 0. -8.  2.]
#  [ 0. -8. -4.]
#  [ 0. -5. -6.]
#  [ 0. -5.  0.]]

# %% [markdown]
# ## Check grid neighborhood (orientation)

# %%
# Go through every correspondence and get neighboring correspondences within a grid radius
# Now remove orientation outliers
MAX_DIST = 30 # np.sqrt(50)
MAX_DEG = 60  # 60 default

mpoints_corrected = mpoints.copy()
fpoints_corrected = fpoints.copy()
cvectors_corrected = cvectors.copy()

orientation_graph = nx.Graph()
orientation_graph.add_nodes_from(range(len(fpoints_corrected)))

for i in range(len(fpoints_corrected)):
    curr_point = fpoints_corrected[i]
    curr_vector = cvectors_corrected[i]
    #print("Current point:", curr_point)
    neighborhood_idx, neighborhood = get_neighborhood(curr_point, fpoints_corrected, MAX_DIST)
    #print("Number of neighbors:", len(neighborhood_idx))
    #print(neighborhood_idx)
    #print(neighborhood)
    
    # Check orientation 
    # Compute the average correspondence vector in the neighborhood
    #average_vector = np.mean(cvectors_corrected[neighborhood_idx], axis=0)
    for j in range(len(neighborhood_idx)):
        nidx = neighborhood_idx[j]
        neighborhood_point = fpoints_corrected[nidx]
        neighborhood_vector = cvectors_corrected[nidx]
        angle_rad, angle_deg = angle_between_vectors(curr_vector, neighborhood_vector)
        if angle_deg > MAX_DEG:
            orientation_graph.add_edge(i, nidx)
            
# Adjust the layout to bring nodes closer together
pos = nx.spring_layout(orientation_graph)

# Visualize the graph
plt.figure(figsize=(5, 5))
nx.draw(orientation_graph, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=20, font_size=4)
plt.title("Orientation node graph")
plt.show()

# %%
MIN_DEGREE = 20

# Get information about degree of each node
degree_dict = dict(orientation_graph.degree())
sorted_nodes = sorted(degree_dict, key=degree_dict.get, reverse=True)

# Filter nodes with degrees above MIN_DEGREE
filtered_nodes = [node for node, degree in degree_dict.items() if degree >= MIN_DEGREE]
filtered_G = orientation_graph.subgraph(filtered_nodes)  # Create a subgraph with the filtered nodes

# Print information
print("Orientation graph")
print("Number of nodes:", len(filtered_G.nodes))
print("Top ten nodes and their degrees:")
for node in sorted_nodes[:10]:
    print(f"\tNode {node}: {degree_dict[node]}")

# Draw the filtered graph
pos = nx.spring_layout(filtered_G, k=0.5, iterations=100)
nx.draw(filtered_G, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=50, font_size=5)
plt.title(f"Orientation graph with nodes of min. degree {MIN_DEGREE}\nNumber of nodes: {len(filtered_G.nodes)}")
plt.show()
# Out:
# Orientation graph
# Number of nodes: 136
# Top ten nodes and their degrees:
# 	Node 960: 52
# 	Node 945: 46
# 	Node 959: 46
# 	Node 929: 44
# 	Node 288: 39
# 	Node 673: 39
# 	Node 1177: 39
# 	Node 1114: 37
# 	Node 1137: 37
# 	Node 1139: 37

# %%
print(f"\tNode {212}: {degree_dict[212]}")
# Out:
# 	Node 212: 21

# %%
# Degree centrality
degree_centrality = nx.degree_centrality(orientation_graph)
sorted_degree_centrality = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
print("Top ten nodes and their degree centrality:")
for node, centrality in sorted_degree_centrality[:10]:
    print(f"\tNode {node}: {centrality}")
print()
    
# Betweenness centrality
betweenness_centrality = nx.betweenness_centrality(orientation_graph)
sorted_betweenness_centrality = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)
print("Top ten nodes and their betweenness centrality:")
for node, centrality in sorted_betweenness_centrality[:10]:
    print(f"\tNode {node}: {centrality}")
print()

# Closeness centrality
closeness_centrality = nx.closeness_centrality(orientation_graph)
sorted_closeness_centrality = sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)
print("Top ten nodes and their closeness centrality:")
for node, centrality in sorted_closeness_centrality[:10]:
    print(f"\tNode {node}: {centrality}")
# Out:
# Top ten nodes and their degree centrality:
# 	Node 960: 0.04176706827309237
# 	Node 945: 0.036947791164658635
# 	Node 959: 0.036947791164658635
# 	Node 929: 0.03534136546184739
# 	Node 288: 0.03132530120481928
# 	Node 673: 0.03132530120481928
# 	Node 1177: 0.03132530120481928
# 	Node 1114: 0.029718875502008035
# 	Node 1137: 0.029718875502008035
# 	Node 1139: 0.029718875502008035
#
# Top ten nodes and their betweenness centrality:
# 	Node 295: 0.08729201710918529
# 	Node 591: 0.08340657800345265
# 	Node 481: 0.08224292455285084
# 	Node 290: 0.07703240639612581
# 	Node 436: 0.061632516771415936
# 	Node 594: 0.05305148327400946
# 	Node 479: 0.052640321450610844
# 	Node 508: 0.049564399838961104
# 	Node 902: 0.04078139705873474
# 	Node 676: 0.03945656459539295
#
# Top ten nodes and their closeness centrality:
# 	Node 617: 0.062058612914396565
# 	Node 594: 0.06162581359922449
# 	Node 713: 0.061246139738004766
# 	Node 727: 0.061246139738004766
# 	Node 627: 0.060871115537542445
# 	Node 641: 0.060871115537542445
# 	Node 673: 0.06075486054224538
# 	Node 685: 0.060043875009285916
# 	Node 739: 0.05999857597118008
# 	Node 712: 0.059683386453883075

# %% [markdown]
# ### Remove conflicts

# %%
top_N = 20
sorted_nodes = sorted_degree_centrality

sorted_nodes = np.array(sorted_nodes)[:, 0]
outlier_indices = np.array(sorted_nodes[:top_N]).astype(int)

# Remove outlier indices from moving and fixed points
mpoints_new = np.delete(mpoints_corrected.copy(), outlier_indices, axis=0)
fpoints_new = np.delete(fpoints_corrected.copy(), outlier_indices, axis=0)
cvectors_new = np.delete(cvectors_corrected.copy(), outlier_indices, axis=0)

print("Number of points originally:", len(mpoints_corrected))
print("Number of points after removal:", len(mpoints_new))
# Out:
# Number of points originally: 1246
# Number of points after removal: 1226

# %%
# Plot number of Jdets over time with number of nodes removed
num_neg_Jdets = []
fixed_resolution = np.zeros((1, 320, 456))
jdet_mean_list = []
jdet_median_list = []
jdet_std_list = []
jdet_min_list = []
jdet_max_list = []

N_to_remove = range(0, len(sorted_degree_centrality), 20)
for N in N_to_remove:
    sorted_nodes = sorted_degree_centrality

    sorted_nodes = np.array(sorted_nodes)[:, 0]
    outlier_indices = np.array(sorted_nodes[:N]).astype(int)

    # Remove outlier indices from moving and fixed points
    mpoints_new = np.delete(mpoints_corrected.copy(), outlier_indices, axis=0)
    fpoints_new = np.delete(fpoints_corrected.copy(), outlier_indices, axis=0)
    cvectors_new = np.delete(cvectors_corrected.copy(), outlier_indices, axis=0)

    deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints_new, fpoints_new)
    jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)
    neg_jdet_count = np.sum(jdet_corrected <= 0)
    num_neg_Jdets.append(neg_jdet_count)
    
    if neg_jdet_count > 0:
        jdet_mean, jdet_median, jdet_std, jdet_min, jdet_max = get_negative_jdet_stats(jdet_corrected, debug=False)
    else: 
        jdet_mean, jdet_median, jdet_std, jdet_min, jdet_max = (0, 0, 0, 0, 0)
    jdet_mean_list.append(jdet_mean)
    jdet_median_list.append(jdet_median)
    jdet_std_list.append(jdet_std)
    jdet_min_list.append(jdet_min)
    jdet_max_list.append(jdet_max)
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12794041633605957s
# Computing dy
# dy calculated in 0.2509944438934326s
# Computing dx
# dx calculated in 0.3490016460418701s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12908101081848145s
# Computing dy
# dy calculated in 0.2553520202636719s
# Computing dx
# dx calculated in 0.35415077209472656s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12779951095581055s
# Computing dy
# dy calculated in 0.25747227668762207s
# Computing dx
# dx calculated in 0.36580491065979004s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12827157974243164s
# Computing dy
# dy calculated in 0.2568049430847168s
# Computing dx
# dx calculated in 0.36286282539367676s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1271376609802246s
# Computing dy
# dy calculated in 0.2558269500732422s
# Computing dx
# dx calculated in 0.3595447540283203s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12847089767456055s
# Computing dy
# dy calculated in 0.25953221321105957s
# Computing dx
# dx calculated in 0.3666524887084961s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12715721130371094s
# Computing dy
# dy calculated in 0.2583963871002197s
# Computing dx
# dx calculated in 0.3610239028930664s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12806248664855957s
# Computing dy
# dy calculated in 0.2599823474884033s
# Computing dx
# dx calculated in 0.36435675621032715s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12723803520202637s
# Computing dy
# dy calculated in 0.25812506675720215s
# Computing dx
# dx calculated in 0.3607981204986572s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12763667106628418s
# Computing dy
# dy calculated in 0.26143789291381836s
# Computing dx
# dx calculated in 0.36513328552246094s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12633156776428223s
# Computing dy
# dy calculated in 0.2600698471069336s
# Computing dx
# dx calculated in 0.3684689998626709s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.127852201461792s
# Computing dy
# dy calculated in 0.2621641159057617s
# Computing dx
# dx calculated in 0.368516206741333s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12696075439453125s
# Computing dy
# dy calculated in 0.26077842712402344s
# Computing dx
# dx calculated in 0.36722660064697266s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1278836727142334s
# Computing dy
# dy calculated in 0.2667560577392578s
# Computing dx
# dx calculated in 0.37674784660339355s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1270606517791748s
# Computing dy
# dy calculated in 0.2612574100494385s
# Computing dx
# dx calculated in 0.3699362277984619s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1275641918182373s
# Computing dy
# dy calculated in 0.2653005123138428s
# Computing dx
# dx calculated in 0.3812699317932129s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1272597312927246s
# Computing dy
# dy calculated in 0.26340174674987793s
# Computing dx
# dx calculated in 0.37609028816223145s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12770390510559082s
# Computing dy
# dy calculated in 0.2633368968963623s
# Computing dx
# dx calculated in 0.3747673034667969s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12749886512756348s
# Computing dy
# dy calculated in 0.26494646072387695s
# Computing dx
# dx calculated in 0.3801450729370117s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12800884246826172s
# Computing dy
# dy calculated in 0.2671520709991455s
# Computing dx
# dx calculated in 0.38416504859924316s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12669086456298828s
# Computing dy
# dy calculated in 0.26700520515441895s
# Computing dx
# dx calculated in 0.38527750968933105s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12832164764404297s
# Computing dy
# dy calculated in 0.2703530788421631s
# Computing dx
# dx calculated in 0.3909623622894287s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12610936164855957s
# Computing dy
# dy calculated in 0.271409273147583s
# Computing dx
# dx calculated in 0.3959357738494873s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1280519962310791s
# Computing dy
# dy calculated in 0.27309441566467285s
# Computing dx
# dx calculated in 0.4025585651397705s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12666034698486328s
# Computing dy
# dy calculated in 0.2725064754486084s
# Computing dx
# dx calculated in 0.40038156509399414s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12765002250671387s
# Computing dy
# dy calculated in 0.27359795570373535s
# Computing dx
# dx calculated in 0.40256428718566895s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12714338302612305s
# Computing dy
# dy calculated in 0.2724790573120117s
# Computing dx
# dx calculated in 0.4002804756164551s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12720441818237305s
# Computing dy
# dy calculated in 0.2743351459503174s
# Computing dx
# dx calculated in 0.4115176200866699s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12742900848388672s
# Computing dy
# dy calculated in 0.27527499198913574s
# Computing dx
# dx calculated in 0.40573620796203613s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1286602020263672s
# Computing dy
# dy calculated in 0.2830169200897217s
# Computing dx
# dx calculated in 0.4168717861175537s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12761592864990234s
# Computing dy
# dy calculated in 0.27955007553100586s
# Computing dx
# dx calculated in 0.4107067584991455s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12818050384521484s
# Computing dy
# dy calculated in 0.29897069931030273s
# Computing dx
# dx calculated in 0.43302464485168457s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1271655559539795s
# Computing dy
# dy calculated in 0.2847585678100586s
# Computing dx
# dx calculated in 0.41724061965942383s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12973904609680176s
# Computing dy
# dy calculated in 0.27525806427001953s
# Computing dx
# dx calculated in 0.40841007232666016s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12655067443847656s
# Computing dy
# dy calculated in 0.27074670791625977s
# Computing dx
# dx calculated in 0.40290164947509766s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12737512588500977s
# Computing dy
# dy calculated in 0.27161526679992676s
# Computing dx
# dx calculated in 0.4069533348083496s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1262681484222412s
# Computing dy
# dy calculated in 0.2690255641937256s
# Computing dx
# dx calculated in 0.4021899700164795s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12788057327270508s
# Computing dy
# dy calculated in 0.2802770137786865s
# Computing dx
# dx calculated in 0.4167318344116211s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12881088256835938s
# Computing dy
# dy calculated in 0.27292728424072266s
# Computing dx
# dx calculated in 0.40672802925109863s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12844228744506836s
# Computing dy
# dy calculated in 0.2803492546081543s
# Computing dx
# dx calculated in 0.41641831398010254s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12702536582946777s
# Computing dy
# dy calculated in 0.27382898330688477s
# Computing dx
# dx calculated in 0.40772414207458496s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12767863273620605s
# Computing dy
# dy calculated in 0.28618454933166504s
# Computing dx
# dx calculated in 0.42644524574279785s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12759089469909668s
# Computing dy
# dy calculated in 0.2775723934173584s
# Computing dx
# dx calculated in 0.41390061378479004s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12942719459533691s
# Computing dy
# dy calculated in 0.28339672088623047s
# Computing dx
# dx calculated in 0.42557477951049805s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12817859649658203s
# Computing dy
# dy calculated in 0.28738832473754883s
# Computing dx
# dx calculated in 0.4245600700378418s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1282939910888672s
# Computing dy
# dy calculated in 0.27803707122802734s
# Computing dx
# dx calculated in 0.4191160202026367s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12688493728637695s
# Computing dy
# dy calculated in 0.27902817726135254s
# Computing dx
# dx calculated in 0.4186367988586426s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12741899490356445s
# Computing dy
# dy calculated in 0.2881193161010742s
# Computing dx
# dx calculated in 0.4288914203643799s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12622356414794922s
# Computing dy
# dy calculated in 0.2862682342529297s
# Computing dx
# dx calculated in 0.4344351291656494s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1275486946105957s
# Computing dy
# dy calculated in 0.2917366027832031s
# Computing dx
# dx calculated in 0.43985438346862793s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1262962818145752s
# Computing dy
# dy calculated in 0.3094673156738281s
# Computing dx
# dx calculated in 0.46933484077453613s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1288588047027588s
# Computing dy
# dy calculated in 0.2952733039855957s
# Computing dx
# dx calculated in 0.44321441650390625s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13186073303222656s
# Computing dy
# dy calculated in 0.289522647857666s
# Computing dx
# dx calculated in 0.44597506523132324s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13020873069763184s
# Computing dy
# dy calculated in 0.2913322448730469s
# Computing dx
# dx calculated in 0.44867801666259766s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12996554374694824s
# Computing dy
# dy calculated in 0.29282283782958984s
# Computing dx
# dx calculated in 0.44535326957702637s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1308915615081787s
# Computing dy
# dy calculated in 0.30685949325561523s
# Computing dx
# dx calculated in 0.4633462429046631s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13048386573791504s
# Computing dy
# dy calculated in 0.28685879707336426s
# Computing dx
# dx calculated in 0.4427974224090576s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13161325454711914s
# Computing dy
# dy calculated in 0.2851386070251465s
# Computing dx
# dx calculated in 0.43766260147094727s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13049697875976562s
# Computing dy
# dy calculated in 0.28279566764831543s
# Computing dx
# dx calculated in 0.43743252754211426s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1310882568359375s
# Computing dy
# dy calculated in 0.28264451026916504s
# Computing dx
# dx calculated in 0.4371035099029541s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1300511360168457s
# Computing dy
# dy calculated in 0.2842073440551758s
# Computing dx
# dx calculated in 0.4361405372619629s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13083267211914062s
# Computing dy
# dy calculated in 0.31557464599609375s
# Computing dx
# dx calculated in 0.497081995010376s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12969517707824707s
# Computing dy
# dy calculated in 0.12989306449890137s
# Computing dx
# dx calculated in 0.13007450103759766s
# SITK deformation shape: (1, 320, 456, 3)

# %%
# Number of Jdets
plt.figure(figsize=(10, 5))
plt.plot(N_to_remove, num_neg_Jdets, marker='o', linestyle='-', color='r')
plt.xlabel('Number of nodes removed')
plt.ylabel('Number of negative Jdets')
plt.title('Number of negative Jdets over number of nodes removed\n(removing nodes with highest orientation degree centrality)')
plt.grid(True)
plt.show()

# Jdet mean
plt.figure(figsize=(10, 5))
plt.plot(N_to_remove, jdet_mean_list, marker='o', linestyle='-', color='r')
plt.xlabel('Number of nodes removed')
plt.ylabel('Negative Jdet mean')
plt.title('Negative Jdet mean over number of nodes removed\n(removing nodes with highest orientation degree centrality)')
plt.grid(True)
plt.show()

# Jdet median
plt.figure(figsize=(10, 5))
plt.plot(N_to_remove, jdet_median_list, marker='o', linestyle='-', color='r')
plt.xlabel('Number of nodes removed')
plt.ylabel('Negative Jdet median')
plt.title('Negative Jdet median over number of nodes removed\n(removing nodes with highest orientation degree centrality)')
plt.grid(True)
plt.show()

# Jdet min
plt.figure(figsize=(10, 5))
plt.plot(N_to_remove, jdet_min_list, marker='o', linestyle='-', color='r')
plt.xlabel('Number of nodes removed')
plt.ylabel('Negative Jdet min')
plt.title('Negative Jdet min over number of nodes removed\n(removing nodes with highest orientation degree centrality)')
plt.grid(True)
plt.show()

# %%
fixed_resolution = np.zeros((1, 320, 456))

# Compute the 3D Laplacian of the ORIGINAL points and retrieve the Jacobian determinant field
deformation, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints, fpoints)
jdet = jacobian.sitk_jacobian_determinant(deformation)

# Compute the 3D Laplacian of the NEW CORRECTED points and retrieve the Jacobian determinant field
deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints_new, fpoints_new)
jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)

# Print the number of negative or zero Jacobian determinants
print("\nBefore - number of negative or zero Jacobian determinants:", np.sum(jdet <= 0))
print("Before - minimum Jacobian determinant:", jdet.min())
print("Before - maximum Jacobian determinant:", jdet.max())
print()

print("After - number of negative or zero Jacobian determinants:", np.sum(jdet_corrected <= 0))
print("After - minimum Jacobian determinant:", jdet_corrected.min())
print("After - maximum Jacobian determinant:", jdet_corrected.max())
print() 

if np.sum(jdet_corrected <= 0) > 0:
    get_negative_jdet_stats(jdet_corrected, debug=True)

# Plot the Jacobian determinant values of the original
norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints[:, 2], mpoints[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (before)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (before)")
plt.show()

# Plot the Jacobian determinant values of the corrected
norm = mcolors.TwoSlopeNorm(vmin=min(jdet_corrected.min(), -1), vcenter=0, vmax=jdet_corrected.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints_new[:, 2], mpoints_new[:, 1], c="g", s=1)
plt.scatter(fpoints_new[:, 2], fpoints_new[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (after)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (after)")
plt.show()
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1317613124847412s
# Computing dy
# dy calculated in 0.25989341735839844s
# Computing dx
# dx calculated in 0.35977673530578613s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13202667236328125s
# Computing dy
# dy calculated in 0.1322493553161621s
# Computing dx
# dx calculated in 0.13246560096740723s
# SITK deformation shape: (1, 320, 456, 3)
#
# Before - number of negative or zero Jacobian determinants: 168
# Before - minimum Jacobian determinant: -4.141267670622895
# Before - maximum Jacobian determinant: 8.847872374160026
#
# After - number of negative or zero Jacobian determinants: 0
# After - minimum Jacobian determinant: 1.0
# After - maximum Jacobian determinant: 1.0

# %% [markdown]
# ## Check grid neighborhood (magnitude)

# %%
# Go through every correspondence and get neighboring correspondences within a grid radius
# Now remove orientation outliers
MAX_DIST = 20 # np.sqrt(50)

# Now run magnitude
MIN_MAGNITUDE_DIFF = 0.7
MAX_MAGNITUDE_DIFF = 1.3
DEBUG = False


mpoints_corrected = mpoints.copy()
fpoints_corrected = fpoints.copy()
cvectors_corrected = cvectors.copy()
magnitudes = np.linalg.norm(cvectors_corrected, axis=1)

magnitude_graph = nx.Graph()
magnitude_graph.add_nodes_from(range(len(fpoints_corrected)))

for i in range(len(fpoints_corrected)):
    curr_point = fpoints_corrected[i]
    curr_magnitude = magnitudes[i]
    neighborhood_idx, neighborhood = get_neighborhood(curr_point, fpoints_corrected, MAX_DIST)
    
    # Check magnitude 
    for j in range(len(neighborhood_idx)):
        nidx = neighborhood_idx[j]
        neighborhood_point = fpoints_corrected[nidx]
        neighborhood_magnitude = magnitudes[nidx]
        if curr_magnitude != 0:
            magnitude_scale = neighborhood_magnitude / curr_magnitude
        else:  # If the magnitude is zero, set the scale to 1
            magnitude_scale = 1
        
        is_magnitude_valid = MIN_MAGNITUDE_DIFF < magnitude_scale < MAX_MAGNITUDE_DIFF
        if not is_magnitude_valid:
            magnitude_graph.add_edge(i, nidx)
            
# Adjust the layout to bring nodes closer together
pos = nx.spring_layout(magnitude_graph, k=0.5, iterations=250)

# Visualize the graph
plt.figure(figsize=(5, 5))
nx.draw(magnitude_graph, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=20, font_size=5)
plt.title("Magnitude graph")
plt.show()

# %%
MIN_DEGREE = 1

# Get information about degree of each node
degree_dict = dict(magnitude_graph.degree())
sorted_nodes = sorted(degree_dict, key=degree_dict.get, reverse=True)

# Filter nodes with degrees above MIN_DEGREE
filtered_nodes = [node for node, degree in degree_dict.items() if degree >= MIN_DEGREE]
filtered_G = magnitude_graph.subgraph(filtered_nodes)  # Create a subgraph with the filtered nodes

# Print information
print("Magnitude graph")
print("Number of nodes:", len(filtered_G.nodes))
print("Top ten nodes and their degrees:")
for node in sorted_nodes[:10]:
    print(f"\tNode {node}: {degree_dict[node]}")

# Draw the filtered graph
pos = nx.spring_layout(filtered_G, k=0.5, iterations=50)
nx.draw(filtered_G, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=200, font_size=10)
plt.title(f"Magnitude graph with nodes of min. degree {MIN_DEGREE}")
plt.show()
# Out:
# Magnitude graph
# Number of nodes: 1213
# Top ten nodes and their degrees:
# 	Node 897: 41
# 	Node 846: 38
# 	Node 379: 37
# 	Node 594: 37
# 	Node 690: 35
# 	Node 712: 34
# 	Node 389: 33
# 	Node 924: 33
# 	Node 261: 32
# 	Node 479: 32

# %%
# Degree centrality
degree_centrality = nx.degree_centrality(magnitude_graph)
sorted_degree_centrality = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)
print("Top ten nodes and their degree centrality:")
for node, centrality in sorted_degree_centrality[:10]:
    print(f"\tNode {node}: {centrality}")
print()
    
# Betweenness centrality
betweenness_centrality = nx.betweenness_centrality(magnitude_graph)
sorted_betweenness_centrality = sorted(betweenness_centrality.items(), key=lambda x: x[1], reverse=True)
print("Top ten nodes and their betweenness centrality:")
for node, centrality in sorted_betweenness_centrality[:10]:
    print(f"\tNode {node}: {centrality}")
print()

# Closeness centrality
closeness_centrality = nx.closeness_centrality(magnitude_graph)
sorted_closeness_centrality = sorted(closeness_centrality.items(), key=lambda x: x[1], reverse=True)
print("Top ten nodes and their closeness centrality:")
for node, centrality in sorted_closeness_centrality[:10]:
    print(f"\tNode {node}: {centrality}")
# Out:
# Top ten nodes and their degree centrality:
# 	Node 897: 0.03293172690763052
# 	Node 846: 0.030522088353413655
# 	Node 379: 0.029718875502008035
# 	Node 594: 0.029718875502008035
# 	Node 690: 0.02811244979919679
# 	Node 712: 0.027309236947791166
# 	Node 389: 0.026506024096385545
# 	Node 924: 0.026506024096385545
# 	Node 261: 0.02570281124497992
# 	Node 479: 0.02570281124497992
#
# Top ten nodes and their betweenness centrality:
# 	Node 386: 0.019916658510178927
# 	Node 119: 0.01778667753499301
# 	Node 359: 0.015993609425733066
# 	Node 647: 0.015836565340992516
# 	Node 641: 0.015727518511666854
# 	Node 444: 0.015173597419473703
# 	Node 294: 0.014830203693457255
# 	Node 473: 0.01453777977153966
# 	Node 509: 0.01359099092989013
# 	Node 414: 0.013501838716357586
#
# Top ten nodes and their closeness centrality:
# 	Node 439: 0.049623310761293345
# 	Node 389: 0.048948433734939754
# 	Node 497: 0.048714603637479856
# 	Node 398: 0.048637155936943316
# 	Node 489: 0.048444609793091606
# 	Node 426: 0.04798866052445074
# 	Node 460: 0.047913502089800074
# 	Node 422: 0.04783857870889343
# 	Node 412: 0.04780120481927711
# 	Node 479: 0.04780120481927711

# %%
top_N = 200
sorted_nodes = sorted_closeness_centrality

sorted_nodes = np.array(sorted_nodes)[:, 0]
outlier_indices = np.array(sorted_nodes[:top_N]).astype(int)

# Remove outlier indices from moving and fixed points
mpoints_new = np.delete(mpoints_corrected.copy(), outlier_indices, axis=0)
fpoints_new = np.delete(fpoints_corrected.copy(), outlier_indices, axis=0)
cvectors_new = np.delete(cvectors_corrected.copy(), outlier_indices, axis=0)

print("Number of points originally:", len(mpoints_corrected))
print("Number of points after removal:", len(mpoints_new))

##############################################################################################################

fixed_resolution = np.zeros((1, 320, 456))

# Compute the 3D Laplacian of the ORIGINAL points and retrieve the Jacobian determinant field
deformation, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints, fpoints)
jdet = jacobian.sitk_jacobian_determinant(deformation)

# Compute the 3D Laplacian of the NEW CORRECTED points and retrieve the Jacobian determinant field
deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints_new, fpoints_new)
jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)

# Print the number of negative or zero Jacobian determinants
print("\nBefore - number of negative or zero Jacobian determinants:", np.sum(jdet <= 0))
print("Before - minimum Jacobian determinant:", jdet.min())
print("Before - maximum Jacobian determinant:", jdet.max())
print()

print("After - number of negative or zero Jacobian determinants:", np.sum(jdet_corrected <= 0))
print("After - minimum Jacobian determinant:", jdet_corrected.min())
print("After - maximum Jacobian determinant:", jdet_corrected.max())
print() 

if np.sum(jdet_corrected <= 0) > 0:
    get_negative_jdet_stats(jdet_corrected, debug=True)

# Plot the Jacobian determinant values of the original
norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints[:, 2], mpoints[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (before)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (before)")
plt.show()

# Plot the Jacobian determinant values of the corrected
norm = mcolors.TwoSlopeNorm(vmin=min(jdet_corrected.min(), -1), vcenter=0, vmax=jdet_corrected.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints_new[:, 2], mpoints_new[:, 1], c="g", s=1)
plt.scatter(fpoints_new[:, 2], fpoints_new[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (after)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (after)")
plt.show()
# Out:
# Number of points originally: 1246
# Number of points after removal: 1046
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1272110939025879s
# Computing dy
# dy calculated in 0.25562405586242676s
# Computing dx
# dx calculated in 0.356856107711792s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12793350219726562s
# Computing dy
# dy calculated in 0.25874805450439453s
# Computing dx
# dx calculated in 0.3622097969055176s
# SITK deformation shape: (1, 320, 456, 3)
#
# Before - number of negative or zero Jacobian determinants: 168
# Before - minimum Jacobian determinant: -4.141267670622895
# Before - maximum Jacobian determinant: 8.847872374160026
#
# After - number of negative or zero Jacobian determinants: 130
# After - minimum Jacobian determinant: -4.1242445371392495
# After - maximum Jacobian determinant: 8.838854257248265
#
# Number of negative Jacobian determinants: 130
# Average negative Jacobian determinant: -0.5249106246294108
# Median negative Jacobian determinant: -0.29473669363104893
# Standard deviation of negative Jacobian determinants: 0.6738333548927673
# Minimum negative Jacobian determinant: -4.1242445371392495
# Maximum negative Jacobian determinant: -0.005091487908634285

# %%
# Plot number of Jdets over time with number of nodes removed
num_neg_Jdets = []
fixed_resolution = np.zeros((1, 320, 456))
jdet_mean_list = []
jdet_median_list = []
jdet_std_list = []
jdet_min_list = []
jdet_max_list = []

N_to_remove = range(0, len(sorted_degree_centrality), 20)
for N in N_to_remove:
    sorted_nodes = sorted_degree_centrality

    sorted_nodes = np.array(sorted_nodes)[:, 0]
    outlier_indices = np.array(sorted_nodes[:N]).astype(int)

    # Remove outlier indices from moving and fixed points
    mpoints_new = np.delete(mpoints_corrected.copy(), outlier_indices, axis=0)
    fpoints_new = np.delete(fpoints_corrected.copy(), outlier_indices, axis=0)
    cvectors_new = np.delete(cvectors_corrected.copy(), outlier_indices, axis=0)

    deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints_new, fpoints_new)
    jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)
    neg_jdet_count = np.sum(jdet_corrected <= 0)
    num_neg_Jdets.append(neg_jdet_count)
    
    if neg_jdet_count > 0:
        jdet_mean, jdet_median, jdet_std, jdet_min, jdet_max = get_negative_jdet_stats(jdet_corrected, debug=False)
    else: 
        jdet_mean, jdet_median, jdet_std, jdet_min, jdet_max = (0, 0, 0, 0, 0)
    jdet_mean_list.append(jdet_mean)
    jdet_median_list.append(jdet_median)
    jdet_std_list.append(jdet_std)
    jdet_min_list.append(jdet_min)
    jdet_max_list.append(jdet_max)
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13067364692687988s
# Computing dy
# dy calculated in 0.25176477432250977s
# Computing dx
# dx calculated in 0.3491976261138916s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1270911693572998s
# Computing dy
# dy calculated in 0.24904584884643555s
# Computing dx
# dx calculated in 0.3502945899963379s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12897920608520508s
# Computing dy
# dy calculated in 0.25460338592529297s
# Computing dx
# dx calculated in 0.3581244945526123s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12766718864440918s
# Computing dy
# dy calculated in 0.2556791305541992s
# Computing dx
# dx calculated in 0.35973548889160156s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12739324569702148s
# Computing dy
# dy calculated in 0.26285481452941895s
# Computing dx
# dx calculated in 0.36630892753601074s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12933897972106934s
# Computing dy
# dy calculated in 0.26212048530578613s
# Computing dx
# dx calculated in 0.36493611335754395s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12657666206359863s
# Computing dy
# dy calculated in 0.2567629814147949s
# Computing dx
# dx calculated in 0.3584740161895752s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12734627723693848s
# Computing dy
# dy calculated in 0.25888586044311523s
# Computing dx
# dx calculated in 0.36180973052978516s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12673282623291016s
# Computing dy
# dy calculated in 0.2591099739074707s
# Computing dx
# dx calculated in 0.3612656593322754s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1276240348815918s
# Computing dy
# dy calculated in 0.2576100826263428s
# Computing dx
# dx calculated in 0.3604743480682373s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12700176239013672s
# Computing dy
# dy calculated in 0.25858426094055176s
# Computing dx
# dx calculated in 0.36353564262390137s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12784361839294434s
# Computing dy
# dy calculated in 0.25922703742980957s
# Computing dx
# dx calculated in 0.36541080474853516s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12600207328796387s
# Computing dy
# dy calculated in 0.2574636936187744s
# Computing dx
# dx calculated in 0.36231064796447754s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12785768508911133s
# Computing dy
# dy calculated in 0.2570500373840332s
# Computing dx
# dx calculated in 0.3642921447753906s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12679457664489746s
# Computing dy
# dy calculated in 0.2627387046813965s
# Computing dx
# dx calculated in 0.367403507232666s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1288599967956543s
# Computing dy
# dy calculated in 0.26258015632629395s
# Computing dx
# dx calculated in 0.36954188346862793s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13326787948608398s
# Computing dy
# dy calculated in 0.26740550994873047s
# Computing dx
# dx calculated in 0.3728163242340088s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13270878791809082s
# Computing dy
# dy calculated in 0.2668933868408203s
# Computing dx
# dx calculated in 0.3753700256347656s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1310431957244873s
# Computing dy
# dy calculated in 0.26648402214050293s
# Computing dx
# dx calculated in 0.37519288063049316s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13211607933044434s
# Computing dy
# dy calculated in 0.2700939178466797s
# Computing dx
# dx calculated in 0.38071107864379883s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1309199333190918s
# Computing dy
# dy calculated in 0.2649412155151367s
# Computing dx
# dx calculated in 0.37224340438842773s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1317582130432129s
# Computing dy
# dy calculated in 0.268207311630249s
# Computing dx
# dx calculated in 0.3783583641052246s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13012146949768066s
# Computing dy
# dy calculated in 0.2673623561859131s
# Computing dx
# dx calculated in 0.38117265701293945s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13224267959594727s
# Computing dy
# dy calculated in 0.2719261646270752s
# Computing dx
# dx calculated in 0.3870973587036133s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13030266761779785s
# Computing dy
# dy calculated in 0.267789363861084s
# Computing dx
# dx calculated in 0.38079380989074707s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13186931610107422s
# Computing dy
# dy calculated in 0.2708139419555664s
# Computing dx
# dx calculated in 0.3857705593109131s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1310443878173828s
# Computing dy
# dy calculated in 0.2681398391723633s
# Computing dx
# dx calculated in 0.3806271553039551s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1311039924621582s
# Computing dy
# dy calculated in 0.26880717277526855s
# Computing dx
# dx calculated in 0.3847079277038574s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13013410568237305s
# Computing dy
# dy calculated in 0.2669391632080078s
# Computing dx
# dx calculated in 0.3819589614868164s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1315474510192871s
# Computing dy
# dy calculated in 0.2700519561767578s
# Computing dx
# dx calculated in 0.38765525817871094s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1308908462524414s
# Computing dy
# dy calculated in 0.2753121852874756s
# Computing dx
# dx calculated in 0.3900294303894043s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1314849853515625s
# Computing dy
# dy calculated in 0.2679269313812256s
# Computing dx
# dx calculated in 0.3836841583251953s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13124394416809082s
# Computing dy
# dy calculated in 0.27260446548461914s
# Computing dx
# dx calculated in 0.39093756675720215s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1310725212097168s
# Computing dy
# dy calculated in 0.26888322830200195s
# Computing dx
# dx calculated in 0.38476109504699707s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12653756141662598s
# Computing dy
# dy calculated in 0.267925500869751s
# Computing dx
# dx calculated in 0.38824033737182617s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12785124778747559s
# Computing dy
# dy calculated in 0.2707674503326416s
# Computing dx
# dx calculated in 0.39210081100463867s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13800740242004395s
# Computing dy
# dy calculated in 0.2827732563018799s
# Computing dx
# dx calculated in 0.40602684020996094s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12844061851501465s
# Computing dy
# dy calculated in 0.2821841239929199s
# Computing dx
# dx calculated in 0.41260266304016113s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1269078254699707s
# Computing dy
# dy calculated in 0.2715773582458496s
# Computing dx
# dx calculated in 0.39953088760375977s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1276545524597168s
# Computing dy
# dy calculated in 0.2724156379699707s
# Computing dx
# dx calculated in 0.40606093406677246s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1268608570098877s
# Computing dy
# dy calculated in 0.27451443672180176s
# Computing dx
# dx calculated in 0.4084782600402832s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12891077995300293s
# Computing dy
# dy calculated in 0.2739992141723633s
# Computing dx
# dx calculated in 0.41158127784729004s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13102078437805176s
# Computing dy
# dy calculated in 0.2833096981048584s
# Computing dx
# dx calculated in 0.4199087619781494s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12851405143737793s
# Computing dy
# dy calculated in 0.27673840522766113s
# Computing dx
# dx calculated in 0.41703200340270996s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12755465507507324s
# Computing dy
# dy calculated in 0.2789936065673828s
# Computing dx
# dx calculated in 0.41806674003601074s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12825846672058105s
# Computing dy
# dy calculated in 0.27818965911865234s
# Computing dx
# dx calculated in 0.4204730987548828s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1275923252105713s
# Computing dy
# dy calculated in 0.2788577079772949s
# Computing dx
# dx calculated in 0.42167186737060547s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12778997421264648s
# Computing dy
# dy calculated in 0.2765171527862549s
# Computing dx
# dx calculated in 0.4215724468231201s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12691044807434082s
# Computing dy
# dy calculated in 0.28056764602661133s
# Computing dx
# dx calculated in 0.42885899543762207s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12689566612243652s
# Computing dy
# dy calculated in 0.2773401737213135s
# Computing dx
# dx calculated in 0.4274873733520508s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12672114372253418s
# Computing dy
# dy calculated in 0.2773723602294922s
# Computing dx
# dx calculated in 0.42409205436706543s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12820196151733398s
# Computing dy
# dy calculated in 0.2799508571624756s
# Computing dx
# dx calculated in 0.4298210144042969s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12734723091125488s
# Computing dy
# dy calculated in 0.2820930480957031s
# Computing dx
# dx calculated in 0.4279778003692627s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12829995155334473s
# Computing dy
# dy calculated in 0.2807145118713379s
# Computing dx
# dx calculated in 0.43253302574157715s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1269831657409668s
# Computing dy
# dy calculated in 0.27908992767333984s
# Computing dx
# dx calculated in 0.42690110206604004s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12815117835998535s
# Computing dy
# dy calculated in 0.2879810333251953s
# Computing dx
# dx calculated in 0.4393479824066162s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12660932540893555s
# Computing dy
# dy calculated in 0.28688955307006836s
# Computing dx
# dx calculated in 0.44289183616638184s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12812495231628418s
# Computing dy
# dy calculated in 0.29344844818115234s
# Computing dx
# dx calculated in 0.4588603973388672s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12755179405212402s
# Computing dy
# dy calculated in 0.2949502468109131s
# Computing dx
# dx calculated in 0.4618222713470459s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.12764644622802734s
# Computing dy
# dy calculated in 0.3587605953216553s
# Computing dx
# dx calculated in 0.5571146011352539s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13066911697387695s
# Computing dy
# dy calculated in 0.3186028003692627s
# Computing dx
# dx calculated in 0.5078122615814209s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.129563570022583s
# Computing dy
# dy calculated in 0.3210914134979248s
# Computing dx
# dx calculated in 0.5095953941345215s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.13204121589660645s
# Computing dy
# dy calculated in 0.29009294509887695s
# Computing dx
# dx calculated in 0.5031242370605469s
# SITK deformation shape: (1, 320, 456, 3)

# %%
# Number of Jdets
plt.figure(figsize=(10, 5))
plt.plot(N_to_remove, num_neg_Jdets, marker='o', linestyle='-', color='r')
plt.xlabel('Number of nodes removed')
plt.ylabel('Number of negative Jdets')
plt.title('Number of negative Jdets over number of nodes removed\n(removing nodes with highest magnitude degree centrality)')
plt.grid(True)
plt.show()

# Jdet mean
plt.figure(figsize=(10, 5))
plt.plot(N_to_remove, jdet_mean_list, marker='o', linestyle='-', color='r')
plt.xlabel('Number of nodes removed')
plt.ylabel('Negative Jdet mean')
plt.title('Negative Jdet mean over number of nodes removed\n(removing nodes with highest magnitude degree centrality)')
plt.grid(True)
plt.show()

# Jdet median
plt.figure(figsize=(10, 5))
plt.plot(N_to_remove, jdet_median_list, marker='o', linestyle='-', color='r')
plt.xlabel('Number of nodes removed')
plt.ylabel('Negative Jdet median')
plt.title('Negative Jdet median over number of nodes removed\n(removing nodes with highest magnitude degree centrality)')
plt.grid(True)
plt.show()

# Jdet min
plt.figure(figsize=(10, 5))
plt.plot(N_to_remove, jdet_min_list, marker='o', linestyle='-', color='r')
plt.xlabel('Number of nodes removed')
plt.ylabel('Negative Jdet min')
plt.title('Negative Jdet min over number of nodes removed\n(removing nodes with highest magnitude degree centrality)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Combine both graphs together

# %%
def combine_graphs_with_weights(G1, G2):
    """
    Combine two graphs into a single weighted graph.
    
    Parameters:
    G1, G2 (networkx.Graph): The input graphs to combine.
    
    Returns:
    networkx.Graph: The combined weighted graph.
    """
    combined_graph = nx.Graph()
    
    # Add nodes from the first graph
    combined_graph.add_nodes_from(G1.nodes())
    combined_graph.add_nodes_from(G2.nodes())

    # Add edges from the first graph with weight 1
    for u, v in G1.edges():
        if combined_graph.has_edge(u, v):
            combined_graph[u][v]['weight'] += 1
        else:
            combined_graph.add_edge(u, v, weight=1)

    # Add edges from the second graph with weight 1
    for u, v in G2.edges():
        if combined_graph.has_edge(u, v):
            combined_graph[u][v]['weight'] += 1
        else:
            combined_graph.add_edge(u, v, weight=1)

    return combined_graph


def get_weighted_degrees(G):
    """
    Get the weighted degrees of all nodes in a weighted graph.
    
    Parameters:
    G (networkx.Graph): The weighted graph.
    
    Returns:
    dict: A dictionary with nodes as keys and their weighted degrees as values.
    """
    return {node: sum(data['weight'] for _, _, data in G.edges(node, data=True)) for node in G.nodes()}



def get_weighted_degree(G, node):
    """
    Get the sum of all weighted connections to a node in a weighted graph.
    
    Parameters:
    G (networkx.Graph): The weighted graph.
    node (int or str): The node to get the weighted degree of.
    
    Returns:
    float: The sum of all weighted connections to the node.
    """
    return sum(data['weight'] for _, _, data in G.edges(node, data=True))

# %%
conflict_graph = combine_graphs_with_weights(orientation_graph, magnitude_graph)

# %%
MIN_WEIGHT = 1

# Get the weighted degrees
weighted_degrees = get_weighted_degrees(conflict_graph)
# Sort the nodes by weighted degree in descending order and get the top 10
sorted_weighted_degrees = sorted(weighted_degrees.items(), key=lambda item: item[1], reverse=True)


# Filter nodes with degrees above MIN_DEGREE
filtered_nodes = [node for node, weight in weighted_degrees.items() if weight >= MIN_WEIGHT]
filtered_G = conflict_graph.subgraph(filtered_nodes)  # Create a subgraph with the filtered nodes

# Print information
print("Conflict graph")
print("Number of nodes:", len(filtered_G.nodes))
print("Top 10 nodes by weighted degree:")
for node, weight in sorted_weighted_degrees[:10]:
    print(f"Node {node}: {weight}")

# Draw the filtered graph
pos = nx.spring_layout(filtered_G)
edges = filtered_G.edges(data=True)
weights = [edge[2]['weight'] for edge in edges]

nx.draw(filtered_G, pos, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500, font_size=10, width=weights)
nx.draw_networkx_edge_labels(filtered_G, pos, edge_labels={(u, v): d['weight'] for u, v, d in filtered_G.edges(data=True)})
plt.title(f"Merged conflict graph with min. weight {MIN_WEIGHT}")
plt.show()
# Out:
# Conflict graph
# Number of nodes: 1074
# Top 10 nodes by weighted degree:
# Node 673: 25
# Node 846: 21
# Node 536: 18
# Node 897: 15
# Node 27: 14
# Node 907: 14
# Node 950: 14
# Node 539: 13
# Node 847: 13
# Node 850: 13

# %%
idx = 673
print("Magnitude degree:", magnitude_graph.degree(idx))
print("Orientation degree:", orientation_graph.degree(idx))
print("Conflict degree:", get_weighted_degree(conflict_graph, idx))
# Out:
# Magnitude degree: 13
# Orientation degree: 12
# Conflict degree: 25

# %% [markdown]
# ## Remove conflicts

# %%
top_N = 1240
outlier_indices = np.array(sorted_weighted_degrees[:top_N])[:, 0]

# Remove outlier indices from moving and fixed points
mpoints_new = np.delete(mpoints_corrected.copy(), outlier_indices, axis=0)
fpoints_new = np.delete(fpoints_corrected.copy(), outlier_indices, axis=0)
cvectors_new = np.delete(cvectors_corrected.copy(), outlier_indices, axis=0)

print("Number of points originally:", len(mpoints_corrected))
print("Number of points after removal:", len(mpoints_new))
# Out:
# Number of points originally: 1246
# Number of points after removal: 6

# %%
fixed_resolution = np.zeros((1, 320, 456))

# Compute the 3D Laplacian of the ORIGINAL points and retrieve the Jacobian determinant field
deformation, A, Zd, Yd, Xd = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints, fpoints)
jdet = jacobian.sitk_jacobian_determinant(deformation)

# Compute the 3D Laplacian of the NEW CORRECTED points and retrieve the Jacobian determinant field
deformation_corrected, _, _, _, _ = laplacian.sliceToSlice3DLaplacian(fixed_resolution, mpoints_new, fpoints_new)
jdet_corrected = jacobian.sitk_jacobian_determinant(deformation_corrected)

# Print the number of negative or zero Jacobian determinants
print("\nBefore - number of negative or zero Jacobian determinants:", np.sum(jdet <= 0))
print("Before - minimum Jacobian determinant:", jdet.min())
print("Before - maximum Jacobian determinant:", jdet.max())
print()

print("After - number of negative or zero Jacobian determinants:", np.sum(jdet_corrected <= 0))
print("After - minimum Jacobian determinant:", jdet_corrected.min())
print("After - maximum Jacobian determinant:", jdet_corrected.max())
print() 

if np.sum(jdet_corrected <= 0) > 0:
    get_negative_jdet_stats(jdet_corrected, debug=True)

# Plot the Jacobian determinant values of the original
norm = mcolors.TwoSlopeNorm(vmin=min(jdet.min(), -1), vcenter=0, vmax=jdet.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints[:, 2], mpoints[:, 1], c="g", s=1)
plt.scatter(fpoints[:, 2], fpoints[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (before)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (before)")
plt.show()

# Plot the Jacobian determinant values of the corrected
norm = mcolors.TwoSlopeNorm(vmin=min(jdet_corrected.min(), -1), vcenter=0, vmax=jdet_corrected.max())
plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0], cmap="seismic", norm=norm)
plt.colorbar()
plt.scatter(mpoints_new[:, 2], mpoints_new[:, 1], c="g", s=1)
plt.scatter(fpoints_new[:, 2], fpoints_new[:, 1], c="violet", s=1)
plt.title("Jacobian determinants slice 350 only (after)")
plt.show()

plt.figure(figsize=(10, 5))
plt.imshow(jdet_corrected[0] <= 0, cmap='viridis')
plt.title("Negative Jacobian determinants slice 350 only (after)")
plt.show()
# Out:
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.1031949520111084s
# Computing dy
# dy calculated in 0.2187943458557129s
# Computing dx
# dx calculated in 0.31951475143432617s
# SITK deformation shape: (1, 320, 456, 3)
# fdata.shape (1, 320, 456)
# Building data for Laplacian Sparse Matrix A
# Creating Laplacian Sparse Matrix A
# Computing dz
# dz calculated in 0.10306954383850098s
# Computing dy
# dy calculated in 0.2877821922302246s
# Computing dx
# dx calculated in 0.5113852024078369s
# SITK deformation shape: (1, 320, 456, 3)
#
# Before - number of negative or zero Jacobian determinants: 168
# Before - minimum Jacobian determinant: -4.141267670622895
# Before - maximum Jacobian determinant: 8.847872374160026
#
# After - number of negative or zero Jacobian determinants: 0
# After - minimum Jacobian determinant: 0.14049368113437324
# After - maximum Jacobian determinant: 1.8595064553522513
